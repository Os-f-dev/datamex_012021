# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# api de jobs github una pagina que recolecta ofertas de empleo, en este caso buscaremos solo de python
url='https://jobs.github.com/positions.json?description=python&page=1'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import requests
import pandas as pd
from pandas import json_normalize

# %%
#hacemos la peticion
r = requests.get(url)
r = r.json()
#normalizamos con pandas y lo transformamos en un dataframe
df = json_normalize(r)
df.head()
# Out:
#                                      id       type  \
# 0  57409c21-5271-482a-9eb5-33b21084e7fd  Full Time
# 1  4334779b-e002-4532-99dd-ad4413d75091  Full Time
# 2  f008bcac-872d-42b0-aec2-066949cac1c3  Full Time
# 3  9abd59e0-52c8-4256-a2fa-4e16992916cb  Full Time
# 4  24f63ba1-4511-45cf-b6b1-5d089639598d  Full Time
#
#                                                  url  \
# 0  https://jobs.github.com/positions/57409c21-527...
# 1  https://jobs.github.com/positions/4334779b-e00...
# 2  https://jobs.github.com/positions/f008bcac-872...
# 3  https://jobs.github.com/positions/9abd59e0-52c...
# 4  https://jobs.github.com/positions/24f63ba1-451...
#
#                      created_at            company  \
# 0  Sun Jan 31 22:57:02 UTC 2021  Commonwealth Bank
# 1  Sun Jan 31 22:37:24 UTC 2021  Commonwealth Bank
# 2  Sun Jan 31 14:53:15 UTC 2021           Promaton
# 3  Sat Jan 30 02:25:31 UTC 2021              iFit
# 4  Fri Jan 29 18:36:11 UTC 2021             Govini
#
# ...

# %%
#obtenemos mas paginas haciendo request en un loop y lo aguardamos en nuestro anterior dataframe
for i in range(2,6):
    try:
        url2='https://jobs.github.com/positions.json?description=python&page='+str(i)
        r = requests.get(url2)
        r = r.json()
        temp = json_normalize(r)
        df = df.append(temp)
    except:
        pass

# %%
#reseteamos los index para ver la cantidad real de registros
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                       id       type  \
# 0   57409c21-5271-482a-9eb5-33b21084e7fd  Full Time
# 1   4334779b-e002-4532-99dd-ad4413d75091  Full Time
# 2   f008bcac-872d-42b0-aec2-066949cac1c3  Full Time
# 3   9abd59e0-52c8-4256-a2fa-4e16992916cb  Full Time
# 4   24f63ba1-4511-45cf-b6b1-5d089639598d  Full Time
# ..                                   ...        ...
# 67  43ddd9a4-4c49-46a0-8b3e-6f1b3e7c522b  Full Time
# 68  6bb39f1f-18a1-45ec-b985-696e2f5a698b  Full Time
# 69  903ceca2-52e9-443c-a639-b2f032204589  Full Time
# 70  b35a2dd9-f16b-46fd-a1ef-223417e7ab77  Full Time
# 71  a7c16735-0426-47aa-9d61-97388054f81b  Full Time
#
#                                                   url  \
# 0   https://jobs.github.com/positions/57409c21-527...
# 1   https://jobs.github.com/positions/4334779b-e00...
# 2   https://jobs.github.com/positions/f008bcac-872...
# 3   https://jobs.github.com/positions/9abd59e0-52c...
# 4   https://jobs.github.com/positions/24f63ba1-451...
# ...

# %%
#cuantas ofertas de trabajo hay por compañia
df.company.value_counts()
# Out:
# Shell Business operations, Chennai                  4
# Booz Allen                                          3
# Amun                                                2
# Neonomics AS                                        2
# Spanflug Technologies GmbH                          2
# Commonwealth Bank                                   2
# WaveSense                                           2
# CompuGroup Medical SE & Co. KGaA                    2
# Ignitia AB                                          2
# CircleBlack, Inc                                    1
# Channable                                           1
# DEVK Versicherungen                                 1
# TubeScience                                         1
# https://www.kranus-health.de                        1
# FRIDAY                                              1
# Alta Planning + Design, Inc.                        1
# Govini                                              1
# ...

# %%
#perfiles mas buscados
df.title.value_counts()
# Out:
# Software Engineer                               3
# Senior Software Engineer                        2
# CI/CD Engineer (m/f/d)                          1
# Software Engineer - Product                     1
# Software developer Linux (m/f/d)                1
#                                                ..
# Technical Team Lead                             1
# Software Engineer (Data Focus) (all genders)    1
# DevOps Engineer                                 1
# Developer / Solution Engineer (f/m/d)           1
# Full-Stack-Entwickler (m/w/d) docmetric         1
# Name: title, Length: 69, dtype: int64

# %%
#ubicacion del trabajo
df.location.value_counts()
# Out:
# Remote                                           7
# Berlin                                           7
# Chennai                                          4
# London, UK or New York                           4
# Munich                                           3
# United States                                    2
# Sydney, Australia                                2
# Remote Remote [GMT+2 to GMT-5 zone preferred]    2
# Annapolis Junction, MD                           2
# Oslo, Norway                                     2
# Düsseldorf                                       1
# Berlin/Remote                                    1
# Remote | NYC                                     1
# 50668 Köln                                       1
# Remote (North America Only)                      1
# Somerville                                       1
# Alsdorf (Germany)                                1
# Memphis, TN                                      1
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
