# %% [markdown]
# ## Challenge 2: Sets
#
# There are a lot to learn about Python Sets and the information presented in the lesson is limited due to its length. To learn Python Sets in depth you are strongly encouraged to review the W3Schools tutorial on [Python Sets Examples and Methods](https://www.w3schools.com/python/python_sets.asp) before you work on this lab. Some difficult questions in this lab have their solutions in the W3Schools tutorial.
#
# #### First, import the Python `random` libary

# %%
import random
from random import randint

# %% [markdown]
# #### In the cell below, create a list named `sample_list_1` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * Each value in the list is unique.
#
# Print `sample_list_1` to review its values
#
# *Hint: use `random.sample` ([reference](https://docs.python.org/3/library/random.html#random.sample)).*

# %%
ls= []
for i in range(80):
    ls.append(random.uniform(0, 100))
print(ls)
# Out:
# [5.299078231050613, 86.16465513393057, 73.58257631123722, 0.7240079468195271, 44.32002662944912, 63.06665317792237, 17.31847221264354, 80.79257906861872, 78.97485745177255, 77.6820493205349, 21.037978891331555, 78.54601667538057, 31.731559613634907, 56.60786419618682, 2.4863354276710714, 20.36625344474807, 10.016684525032392, 91.59822667054497, 37.813892803028104, 72.34092507883392, 14.435723735521854, 5.310403134153696, 77.6835483944557, 59.353124677743175, 93.4449783197881, 77.93395868903728, 32.08467825720999, 56.07579666110285, 48.769610730293536, 13.592367042140962, 64.683477256676, 95.21486845337823, 97.47476141663063, 39.90425031238167, 96.39715335660543, 35.91580596744163, 40.525831980677786, 75.48686478066948, 99.65458424051073, 11.841884172546846, 62.15641159522786, 53.65152155652901, 91.53662349635012, 46.52000935372749, 27.19628902555734, 51.25596429852794, 40.8061259669346, 38.17473937167052, 0.9089369422418447, 91.84716936056915, 8.45775015751915, 74.77418634512003, 61.84501467541003, 40.8011001836927, 92.62640981727057, 80.06927170271412, 95.10891788180209, 13.324562709735833, 41.01857440755968, 97.20910892957622, 43.31577152952703, 54.337457465522256, 17.731893523066276, 6.0930207193387265, 20.887063357702797, 14.488217498965861, 28.74199773859153, 76.15739566092141, 40.57010315821032, 96.35950058819088, 17.58237475698683, 31.651456669526233, 86.13940193541492, 48.52458584209565, 89.29076517652015, 69.73091576431864, 17.666918408469, 74.0445452790918, 44.11289856318032, 44.323675404003225]

# %% [markdown]
# #### Convert `sample_list_1` to a set called `set1`. Print the length of the set. Is its length still 80?

# %%
set1 = set(ls)
print(len(set1))
# Out:
# 80

# %% [markdown]
# #### Create another list named `sample_list_2` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * The values in the list don't have to be unique.
#
# *Hint: Use a FOR loop.*

# %%
sample_list_2= []
for i in range(80):
    sample_list_2.append(random.uniform(0, 100))
print(sample_list_2)
# Out:
37.813892803028104, 38.17473937167052, 39.90425031238167, 40.525831980677786, 40.8061259669346, 40.8011001836927, 41.01857440755968, 44.32002662944912, 43.31577152952703, 46.52000935372749, 40.57010315821032, 48.769610730293536, 48.52458584209565, 44.11289856318032, 51.25596429852794, 44.323675404003225, 53.65152155652901, 54.337457465522256, 46.44920946988964, 56.60786419618682, 56.07579666110285, 50.17188479510259, 59.353124677743175, 51.32224942793724, 61.84501467541003, 62.15641159522786, 63.06665317792237, 64.683477256676, 12.729964149192597, 59.127392471584216, 59.93248442722772, 60.48044181277646, 69.73091576431864, 63.533197294854304, 64.06198395132307, 72.34092507883392, 73.58257631123722, 74.77418634512003, 75.48686478066948, 76.15739566092141, 77.6820493205349, 78.97485745177255, 78.54601667538057, 80.79257906861872, 77.6835483944557, 77.93395868903728, 80.06927170271412, 77.30531413975596, 77.32494854956153, 86.16465513393057, 86.13940193541492, 80.42050453624786, 89.29076517652015, 83.84497923185049, 91.59822667054497, 91.53662349635012, 93.4449783197881, 91.84716936056915, 95.21486845337823, 96.39715335660543, 97.47476141663063, 92.62640981727057, 99.65458424051073, 95.10891788180209, 97.20910892957622, 96.35950058819088, 19.30380878358936, 95.47823007205832, 97.71358891316753, 97.38523914673365, 99.9197429844659, 24.72075503156377, 24.249692378508215, 30.172775820328155, 31.939911317854552, 31.94610942186432, 32.39507635780807, 33.07123783627962, 36.76313053846143, 36.12231481526318, 38.4936769882424, 38.703163652076555, 42.8307769869665, 43.45454386141985, 43.84559703380925, 43.440143298424, 47.894514942944255, 48.29616148467717, 48.92046524236734, 50.12674000584553, 51.95463056753674, 53.890798449441924, 56.90779107840564, 6.469008057746084, 66.98928287151153, 68.11185042205358, 69.6749194204698, 69.46605104206978, 70.02334718544486, 22.86534543065608, 73.61438659845359, 23.91705199331582, 74.0445452790918, 23.767946939666185, 74.65901258220516, 74.70270003795683, 74.14563597089571, 76.80923647499827, 27.889210370647167, 78.96676963325038, 78.02976665943403, 29.98379563107193, 30.409769418746645, 31.233786041180235, 84.54615076561755, 86.74096774024251, 10.801973600060178, 88.17487246678857, 88.12155516447936, 90.05376184776213, 91.04936814119203, 94.1374725369558, 94.09269791746834, 95.43161449555653}

# %% [markdown]
# #### What is the relationship among the following values:
#
# * len(set1)
# * len(set2)
# * len(set3)
# * len(set4)
# * len(set5)
#
# Use a math formular to represent that relationship. Test your formular with Python code.

# %%
print(len(set1))
print(len(set2))
print(len(set3))
print(len(set4))
print(len(set5))
len(set3)+len(set4) == len(set5)
len(set1) + len(set2) == len(set5)
# Out:
# 80
# 80
# 80
# 80
# 160
# True

# %% [markdown]
# #### Create an empty set called `set6`.

# %%
set6 = set()
type(set6)
# Out:
# set

# %% [markdown]
# #### Add `set3` and `set5` to `set6` using the Python Set `update` method.

# %%
set6 = set3.update(set5)
# Out:
# None

# %% [markdown]
# #### Check if `set1` and `set6` are equal.

# %%
print(set1 == set6)
# Out:
# False

# %% [markdown]
# #### Check if `set1` contains `set2` using the Python Set `issubset` method. Then check if `set1` contains `set3`.*

# %%
print(set2.issubset(set1))
print(set3.issubset(set1))
# Out:
# False
# False

# %% [markdown]
# #### Using the Python Set `union` method, aggregate `set3`, `set4`, and `set5`. Then aggregate `set1` and `set2`.
#
# #### Check if the aggregated values are equal.

# %%
setu1 = set3.union(set4)
setu2 = setu1.union(set5)
setu3 =  set1.union(set2)
print(setu3==setu2)
# Out:
# True

# %% [markdown]
# #### Using the `pop` method, remove the first element from `set1`.

# %%
u1 = []
u = list(set1)
type(u)
print(u)
u1 = u.pop(3)
print(u1)
# Out:
# [0.7240079468195271, 0.9089369422418447, 2.4863354276710714, 5.299078231050613, 5.310403134153696, 6.0930207193387265, 8.45775015751915, 10.016684525032392, 11.841884172546846, 13.592367042140962, 14.435723735521854, 13.324562709735833, 14.488217498965861, 17.31847221264354, 17.731893523066276, 17.58237475698683, 20.36625344474807, 21.037978891331555, 20.887063357702797, 17.666918408469, 27.19628902555734, 28.74199773859153, 31.731559613634907, 32.08467825720999, 31.651456669526233, 35.91580596744163, 37.813892803028104, 38.17473937167052, 39.90425031238167, 40.525831980677786, 40.8061259669346, 40.8011001836927, 41.01857440755968, 44.32002662944912, 43.31577152952703, 46.52000935372749, 40.57010315821032, 48.769610730293536, 48.52458584209565, 44.11289856318032, 51.25596429852794, 44.323675404003225, 53.65152155652901, 54.337457465522256, 56.60786419618682, 56.07579666110285, 59.353124677743175, 61.84501467541003, 62.15641159522786, 63.06665317792237, 64.683477256676, 69.73091576431864, 72.34092507883392, 73.58257631123722, 74.77418634512003, 75.48686478066948, 76.15739566092141, 77.6820493205349, 78.97485745177255, 78.54601667538057, 80.79257906861872, 77.6835483944557, 77.93395868903728, 80.06927170271412, 86.16465513393057, 86.13940193541492, 89.29076517652015, 91.59822667054497, 91.53662349635012, 93.4449783197881, 91.84716936056915, 95.21486845337823, 96.39715335660543, 97.47476141663063, 92.62640981727057, 99.65458424051073, 95.10891788180209, 97.20910892957622, 96.35950058819088, 74.0445452790918]
# 5.299078231050613

# %% [markdown]
# #### Remove every element in the following list from `set1` if they are present in the set. Print the remaining elements.
#
# ```
# list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]
# ```

# %%
n = len(set1)
list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]
for i in list_to_remove:
     if  i in set1:
        set1.remove(i)
