# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
key = 'hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'

# %%
rest = requests.get(f'https://api.nasa.gov/neo/rest/v1/neo/browse?api_key={key}')
rest
# Out:
# <Response [200]>

# %%
res= rest.json()
res.keys()
# Out:
# dict_keys(['links', 'page', 'near_earth_objects'])

# %%
near_earth_objects = res['near_earth_objects']
near_earth_objects
# Out:
# [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2000433?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2000433',
#   'neo_reference_id': '2000433',
#   'name': '433 Eros (A898 PA)',
#   'name_limited': 'Eros',
#   'designation': '433',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433',
#   'absolute_magnitude_h': 10.4,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 22.1082810359,
#     'estimated_diameter_max': 49.435619262},
#    'meters': {'estimated_diameter_min': 22108.281035909,
#     'estimated_diameter_max': 49435.619261962},
#    'miles': {'estimated_diameter_min': 13.7374446956,
#     'estimated_diameter_max': 30.7178601764},
#    'feet': {'estimated_diameter_min': 72533.7327538517,
#     'estimated_diameter_max': 162190.3570994153}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '658',
#    'orbit_determination_date': '2020-09-06 18:22:27',
#    'first_observation_date': '1893-10-29',
#    'last_observation_date': '2020-09-03',
#    'data_arc_in_days': 46330,
#    'observations_used': 8767,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.148623',
#    'jupiter_tisserand_invariant': '4.582',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.2229512647434284',
#    'semi_major_axis': '1.458045729081037',
#    'inclination': '10.83054121829922',
#    'ascending_node_longitude': '304.2993259000444',
#    'orbital_period': '643.0654021001488',
#    'perihelion_distance': '1.132972589728666',
#    'perihelion_argument': '178.8822959227224',
#    'aphelion_distance': '1.783118868433408',
#    'perihelion_time': '2459159.351922368362',
#    'mean_anomaly': '271.0717325705167',
#    'mean_motion': '.5598186418120109',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2000719?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2000719',
#   'neo_reference_id': '2000719',
#   'name': '719 Albert (A911 TB)',
#   'name_limited': 'Albert',
#   'designation': '719',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719',
#   'absolute_magnitude_h': 15.5,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 2.1113244479,
#     'estimated_diameter_max': 4.7210649881},
#    'meters': {'estimated_diameter_min': 2111.3244478971,
#     'estimated_diameter_max': 4721.0649880552},
#    'miles': {'estimated_diameter_min': 1.3119157835,
#     'estimated_diameter_max': 2.9335328727},
#    'feet': {'estimated_diameter_min': 6926.9177016389,
#     'estimated_diameter_max': 15489.0588554111}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '215',
#    'orbit_determination_date': '2020-12-24 05:55:26',
#    'first_observation_date': '1911-10-04',
#    'last_observation_date': '2020-12-23',
#    'data_arc_in_days': 39893,
#    'observations_used': 1878,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.203482',
#    'jupiter_tisserand_invariant': '3.140',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5465584658893893',
#    'semi_major_axis': '2.638602064219676',
#    'inclination': '11.56748450944226',
#    'ascending_node_longitude': '183.86694755492',
#    'orbital_period': '1565.522355420405',
#    'perihelion_distance': '1.196451767907194',
#    'perihelion_argument': '156.176340057815',
#    'aphelion_distance': '4.080752360532158',
#    'perihelion_time': '2458390.496728247930',
#    'mean_anomaly': '140.2734218840163',
#    'mean_motion': '.2299551959469309',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2000887?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2000887',
#   'neo_reference_id': '2000887',
#   'name': '887 Alinda (A918 AA)',
#   'name_limited': 'Alinda',
#   'designation': '887',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887',
#   'absolute_magnitude_h': 13.8,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 4.6190746028,
#     'estimated_diameter_max': 10.328564805},
#    'meters': {'estimated_diameter_min': 4619.0746028158,
#     'estimated_diameter_max': 10328.5648050391},
#    'miles': {'estimated_diameter_min': 2.870159005,
#     'estimated_diameter_max': 6.4178706415},
#    'feet': {'estimated_diameter_min': 15154.4447199023,
#     'estimated_diameter_max': 33886.3685549643}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '343',
#    'orbit_determination_date': '2021-01-31 06:47:13',
#    'first_observation_date': '1918-02-03',
#    'last_observation_date': '2021-01-30',
#    'data_arc_in_days': 37617,
#    'observations_used': 2049,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.082217',
#    'jupiter_tisserand_invariant': '3.221',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5703317176438265',
#    'semi_major_axis': '2.473736926882441',
#    'inclination': '9.393850619707097',
#    'ascending_node_longitude': '110.434243296083',
#    'orbital_period': '1421.113270604532',
#    'perihelion_distance': '1.062886296374618',
#    'perihelion_argument': '350.4955520605819',
#    'aphelion_distance': '3.884587557390264',
#    'perihelion_time': '2459258.751134668900',
#    'mean_anomaly': '294.5791708487424',
#    'mean_motion': '.2533225235781933',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001036?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001036',
#   'neo_reference_id': '2001036',
#   'name': '1036 Ganymed (A924 UB)',
#   'name_limited': 'Ganymed',
#   'designation': '1036',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036',
#   'absolute_magnitude_h': 9.4,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 35.0392641108,
#     'estimated_diameter_max': 78.3501764334},
#    'meters': {'estimated_diameter_min': 35039.2641108293,
#     'estimated_diameter_max': 78350.176433383},
#    'miles': {'estimated_diameter_min': 21.7723825798,
#     'estimated_diameter_max': 48.6845274806},
#    'feet': {'estimated_diameter_min': 114958.2192653732,
#     'estimated_diameter_max': 257054.3928497004}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '863',
#    'orbit_determination_date': '2021-01-31 06:47:13',
#    'first_observation_date': '1924-10-23',
#    'last_observation_date': '2021-01-30',
#    'data_arc_in_days': 35163,
#    'observations_used': 6664,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.344956',
#    'jupiter_tisserand_invariant': '3.035',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5330461240840629',
#    'semi_major_axis': '2.664724624252425',
#    'inclination': '26.67764044274185',
#    'ascending_node_longitude': '215.5468281945239',
#    'orbital_period': '1588.828164013753',
#    'perihelion_distance': '1.244303491543309',
#    'perihelion_argument': '132.3646330593546',
#    'aphelion_distance': '4.085145756961542',
#    'perihelion_time': '2458979.237312304403',
#    'mean_anomaly': '4.817744136079234',
#    'mean_motion': '.2265820861902117',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001221?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001221',
#   'neo_reference_id': '2001221',
#   'name': '1221 Amor (1932 EA1)',
#   'name_limited': 'Amor',
#   'designation': '1221',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221',
#   'absolute_magnitude_h': 17.7,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7665755735,
#     'estimated_diameter_max': 1.7141150923},
#    'meters': {'estimated_diameter_min': 766.5755735311,
#     'estimated_diameter_max': 1714.1150923063},
#    'miles': {'estimated_diameter_min': 0.4763278307,
#     'estimated_diameter_max': 1.065101409},
#    'feet': {'estimated_diameter_min': 2515.0118046636,
#     'estimated_diameter_max': 5623.7373594423}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '104',
#    'orbit_determination_date': '2020-11-21 05:21:26',
#    'first_observation_date': '1932-03-12',
#    'last_observation_date': '2020-09-14',
#    'data_arc_in_days': 32328,
#    'observations_used': 552,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.10745',
#    'jupiter_tisserand_invariant': '3.781',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.43528495399772',
#    'semi_major_axis': '1.919498150512536',
#    'inclination': '11.87653980721408',
#    'ascending_node_longitude': '171.3270121727965',
#    'orbital_period': '971.3594594940868',
#    'perihelion_distance': '1.083969486367978',
#    'perihelion_argument': '26.69478755345107',
#    'aphelion_distance': '2.755026814657094',
#    'perihelion_time': '2458896.558033524650',
#    'mean_anomaly': '38.52241059207368',
#    'mean_motion': '.3706146025360157',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001566?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001566',
#   'neo_reference_id': '2001566',
#   'name': '1566 Icarus (1949 MA)',
#   'name_limited': 'Icarus',
#   'designation': '1566',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001566',
#   'absolute_magnitude_h': 16.9,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.1080388213,
#     'estimated_diameter_max': 2.4776501261},
#    'meters': {'estimated_diameter_min': 1108.0388212642,
#     'estimated_diameter_max': 2477.6501260554},
#    'miles': {'estimated_diameter_min': 0.6885031904,
#     'estimated_diameter_max': 1.5395399365},
#    'feet': {'estimated_diameter_min': 3635.2980863563,
#     'estimated_diameter_max': 8128.7736395675}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '119',
#    'orbit_determination_date': '2020-09-10 06:23:50',
#    'first_observation_date': '1949-07-01',
#    'last_observation_date': '2020-09-08',
#    'data_arc_in_days': 26002,
#    'observations_used': 1052,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.0342447',
#    'jupiter_tisserand_invariant': '5.298',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.8270213517584103',
#    'semi_major_axis': '1.078168924356222',
#    'inclination': '22.82210584381254',
#    'ascending_node_longitude': '87.9975459324354',
#    'orbital_period': '408.9108574324997',
#    'perihelion_distance': '.186500203111228',
#    'perihelion_argument': '31.39333873322229',
#    'aphelion_distance': '1.969837645601215',
#    'perihelion_time': '2459191.230586607055',
#    'mean_anomaly': '192.0831791807477',
#    'mean_motion': '.8803874816638403',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001580?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001580',
#   'neo_reference_id': '2001580',
#   'name': '1580 Betulia (1950 KA)',
#   'name_limited': 'Betulia',
#   'designation': '1580',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001580',
#   'absolute_magnitude_h': 14.7,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 3.0517923259,
#     'estimated_diameter_max': 6.824015094},
#    'meters': {'estimated_diameter_min': 3051.7923259387,
#     'estimated_diameter_max': 6824.0150940112},
#    'miles': {'estimated_diameter_min': 1.8962952494,
#     'estimated_diameter_max': 4.240245083},
#    'feet': {'estimated_diameter_min': 10012.4423346328,
#     'estimated_diameter_max': 22388.5016810356}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '257',
#    'orbit_determination_date': '2021-01-19 05:27:51',
#    'first_observation_date': '1950-05-22',
#    'last_observation_date': '2021-01-18',
#    'data_arc_in_days': 25809,
#    'observations_used': 1334,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.136137',
#    'jupiter_tisserand_invariant': '3.065',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.4873502062220318',
#    'semi_major_axis': '2.197150031596911',
#    'inclination': '52.09207131550431',
#    'ascending_node_longitude': '62.29781962341903',
#    'orbital_period': '1189.564505785125',
#    'perihelion_distance': '1.126368510597413',
#    'perihelion_argument': '159.5179510015747',
#    'aphelion_distance': '3.267931552596409',
#    'perihelion_time': '2459545.477653098300',
#    'mean_anomaly': '195.0724536910258',
#    'mean_motion': '.3026317599837903',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001620?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001620',
#   'neo_reference_id': '2001620',
#   'name': '1620 Geographos (1951 RA)',
#   'name_limited': 'Geographos',
#   'designation': '1620',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001620',
#   'absolute_magnitude_h': 15.3,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 2.3150212221,
#     'estimated_diameter_max': 5.176544822},
#    'meters': {'estimated_diameter_min': 2315.0212221033,
#     'estimated_diameter_max': 5176.5448219775},
#    'miles': {'estimated_diameter_min': 1.4384870518,
#     'estimated_diameter_max': 3.2165548326},
#    'feet': {'estimated_diameter_min': 7595.2142263253,
#     'estimated_diameter_max': 16983.4153137368}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '610',
#    'orbit_determination_date': '2020-10-02 06:44:01',
#    'first_observation_date': '1951-08-31',
#    'last_observation_date': '2020-04-17',
#    'data_arc_in_days': 25067,
#    'observations_used': 4805,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.0303535',
#    'jupiter_tisserand_invariant': '5.074',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.3354548016359858',
#    'semi_major_axis': '1.245666863802655',
#    'inclination': '13.33704335138623',
#    'ascending_node_longitude': '337.1869752871972',
#    'orbital_period': '507.810053477714',
#    'perihelion_distance': '.8278019331012146',
#    'perihelion_argument': '276.956067654262',
#    'aphelion_distance': '1.663531794504095',
#    'perihelion_time': '2459176.664045134509',
#    'mean_anomaly': '235.112641401838',
#    'mean_motion': '.7089264923657113',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001627?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001627',
#   'neo_reference_id': '2001627',
#   'name': '1627 Ivar (1929 SH)',
#   'name_limited': 'Ivar',
#   'designation': '1627',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001627',
#   'absolute_magnitude_h': 12.7,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 7.6657557353,
#     'estimated_diameter_max': 17.1411509231},
#    'meters': {'estimated_diameter_min': 7665.7557353105,
#     'estimated_diameter_max': 17141.1509230632},
#    'miles': {'estimated_diameter_min': 4.763278307,
#     'estimated_diameter_max': 10.6510140902},
#    'feet': {'estimated_diameter_min': 25150.1180466362,
#     'estimated_diameter_max': 56237.3735944227}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '1011',
#    'orbit_determination_date': '2020-07-12 06:35:44',
#    'first_observation_date': '1929-09-25',
#    'last_observation_date': '2020-06-22',
#    'data_arc_in_days': 33143,
#    'observations_used': 7298,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.111952',
#    'jupiter_tisserand_invariant': '3.879',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.3967830583744957',
#    'semi_major_axis': '1.86327294504367',
#    'inclination': '8.451869889021321',
#    'ascending_node_longitude': '133.1193427586828',
#    'orbital_period': '928.9945022630588',
#    'perihelion_distance': '1.123957807322788',
#    'perihelion_argument': '167.7934626032436',
#    'aphelion_distance': '2.602588082764551',
#    'perihelion_time': '2459267.568113285847',
#    'mean_anomaly': '256.5069001498996',
#    'mean_motion': '.3875157486110295',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001685?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001685',
#   'neo_reference_id': '2001685',
#   'name': '1685 Toro (1948 OA)',
#   'name_limited': 'Toro',
#   'designation': '1685',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001685',
#   'absolute_magnitude_h': 14.3,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 3.6690613753,
#     'estimated_diameter_max': 8.2042706488},
#    'meters': {'estimated_diameter_min': 3669.0613753145,
#     'estimated_diameter_max': 8204.270648822},
#    'miles': {'estimated_diameter_min': 2.2798483358,
#     'estimated_diameter_max': 5.0978958573},
#    'feet': {'estimated_diameter_min': 12037.6033225867,
#     'estimated_diameter_max': 26916.8993154812}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '538',
#    'orbit_determination_date': '2021-01-30 06:46:51',
#    'first_observation_date': '1948-07-17',
#    'last_observation_date': '2021-01-29',
#    'data_arc_in_days': 26494,
#    'observations_used': 3244,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.0506645',
#    'jupiter_tisserand_invariant': '4.715',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.4358371101704305',
#    'semi_major_axis': '1.367586471691055',
#    'inclination': '9.383132393569714',
#    'ascending_node_longitude': '274.2452389405508',
#    'orbital_period': '584.1583931087478',
#    'perihelion_distance': '.7715415359610504',
#    'perihelion_argument': '127.2065877085088',
#    'aphelion_distance': '1.96363140742106',
#    'perihelion_time': '2459113.679632151735',
#    'mean_anomaly': '290.2506510985979',
#    'mean_motion': '.6162712104232009',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001862?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001862',
#   'neo_reference_id': '2001862',
#   'name': '1862 Apollo (1932 HA)',
#   'name_limited': 'Apollo',
#   'designation': '1862',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001862',
#   'absolute_magnitude_h': 16.25,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.4947032424,
#     'estimated_diameter_max': 3.3422580561},
#    'meters': {'estimated_diameter_min': 1494.7032423559,
#     'estimated_diameter_max': 3342.2580560972},
#    'miles': {'estimated_diameter_min': 0.9287652484,
#     'estimated_diameter_max': 2.0767822306},
#    'feet': {'estimated_diameter_min': 4903.8821856511,
#     'estimated_diameter_max': 10965.4139207661}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '313',
#    'orbit_determination_date': '2021-01-20 05:20:00',
#    'first_observation_date': '1930-12-13',
#    'last_observation_date': '2021-01-19',
#    'data_arc_in_days': 32910,
#    'observations_used': 1712,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.0258141',
#    'jupiter_tisserand_invariant': '4.414',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5599167407932545',
#    'semi_major_axis': '1.470345437092072',
#    'inclination': '6.354730724437444',
#    'ascending_node_longitude': '35.6271279237656',
#    'orbital_period': '651.2196463216337',
#    'perihelion_distance': '.6470744121152457',
#    'perihelion_argument': '285.9759611998543',
#    'aphelion_distance': '2.293616462068898',
#    'perihelion_time': '2458840.324426394190',
#    'mean_anomaly': '88.54647863251381',
#    'mean_motion': '.5528088749063907',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001863?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001863',
#   'neo_reference_id': '2001863',
#   'name': '1863 Antinous (1948 EA)',
#   'name_limited': 'Antinous',
#   'designation': '1863',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001863',
#   'absolute_magnitude_h': 15.3,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 2.3150212221,
#     'estimated_diameter_max': 5.176544822},
#    'meters': {'estimated_diameter_min': 2315.0212221033,
#     'estimated_diameter_max': 5176.5448219775},
#    'miles': {'estimated_diameter_min': 1.4384870518,
#     'estimated_diameter_max': 3.2165548326},
#    'feet': {'estimated_diameter_min': 7595.2142263253,
#     'estimated_diameter_max': 16983.4153137368}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '198',
#    'orbit_determination_date': '2021-01-16 06:03:16',
#    'first_observation_date': '1948-03-05',
#    'last_observation_date': '2021-01-16',
#    'data_arc_in_days': 26615,
#    'observations_used': 1044,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.182709',
#    'jupiter_tisserand_invariant': '3.298',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.6065072166601064',
#    'semi_major_axis': '2.258411530649289',
#    'inclination': '18.40043382088493',
#    'ascending_node_longitude': '346.4403101410485',
#    'orbital_period': '1239.661320253209',
#    'perihelion_distance': '.8886686391220981',
#    'perihelion_argument': '268.0670168922298',
#    'aphelion_distance': '3.62815442217648',
#    'perihelion_time': '2458760.096785979125',
#    'mean_anomaly': '69.81354958291149',
#    'mean_motion': '.2904018977751663',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001864?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001864',
#   'neo_reference_id': '2001864',
#   'name': '1864 Daedalus (1971 FA)',
#   'name_limited': 'Daedalus',
#   'designation': '1864',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001864',
#   'absolute_magnitude_h': 14.7,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 3.0517923259,
#     'estimated_diameter_max': 6.824015094},
#    'meters': {'estimated_diameter_min': 3051.7923259387,
#     'estimated_diameter_max': 6824.0150940112},
#    'miles': {'estimated_diameter_min': 1.8962952494,
#     'estimated_diameter_max': 4.240245083},
#    'feet': {'estimated_diameter_min': 10012.4423346328,
#     'estimated_diameter_max': 22388.5016810356}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '543',
#    'orbit_determination_date': '2020-06-13 06:14:23',
#    'first_observation_date': '1971-03-24',
#    'last_observation_date': '2020-06-12',
#    'data_arc_in_days': 17978,
#    'observations_used': 2557,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.269089',
#    'jupiter_tisserand_invariant': '4.336',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.6144701472617778',
#    'semi_major_axis': '1.460916421388319',
#    'inclination': '22.2119602234901',
#    'ascending_node_longitude': '6.621948090247717',
#    'orbital_period': '644.9654981185722',
#    'perihelion_distance': '.563226892800689',
#    'perihelion_argument': '325.6333775511697',
#    'aphelion_distance': '2.358605949975948',
#    'perihelion_time': '2459249.113376950815',
#    'mean_anomaly': '221.2316225234122',
#    'mean_motion': '.5581693920840036',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001865?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001865',
#   'neo_reference_id': '2001865',
#   'name': '1865 Cerberus (1971 UA)',
#   'name_limited': 'Cerberus',
#   'designation': '1865',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001865',
#   'absolute_magnitude_h': 16.7,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.214940408,
#     'estimated_diameter_max': 2.7166893409},
#    'meters': {'estimated_diameter_min': 1214.9404079963,
#     'estimated_diameter_max': 2716.6893408911},
#    'miles': {'estimated_diameter_min': 0.7549287363,
#     'estimated_diameter_max': 1.6880719724},
#    'feet': {'estimated_diameter_min': 3986.0250881707,
#     'estimated_diameter_max': 8913.0230571693}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '345',
#    'orbit_determination_date': '2021-01-12 05:24:30',
#    'first_observation_date': '1971-10-26',
#    'last_observation_date': '2021-01-12',
#    'data_arc_in_days': 17976,
#    'observations_used': 1996,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.156542',
#    'jupiter_tisserand_invariant': '5.592',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.4668531251159767',
#    'semi_major_axis': '1.07999393336823',
#    'inclination': '16.09595516619598',
#    'ascending_node_longitude': '212.9201790880834',
#    'orbital_period': '409.9495374952898',
#    'perihelion_distance': '.5757953904689762',
#    'perihelion_argument': '325.2454993338431',
#    'aphelion_distance': '1.584192476267485',
#    'perihelion_time': '2458996.718935883446',
#    'mean_anomaly': '3.320367404915569',
#    'mean_motion': '.8781568634020871',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001866?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001866',
#   'neo_reference_id': '2001866',
#   'name': '1866 Sisyphus (1972 XA)',
#   'name_limited': 'Sisyphus',
#   'designation': '1866',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001866',
#   'absolute_magnitude_h': 12.4,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 8.801465209,
#     'estimated_diameter_max': 19.6806745089},
#    'meters': {'estimated_diameter_min': 8801.4652090073,
#     'estimated_diameter_max': 19680.6745089397},
#    'miles': {'estimated_diameter_min': 5.4689752384,
#     'estimated_diameter_max': 12.2290004003},
#    'feet': {'estimated_diameter_min': 28876.1991163194,
#     'estimated_diameter_max': 64569.1441559096}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '723',
#    'orbit_determination_date': '2021-01-11 09:47:36',
#    'first_observation_date': '1955-01-26',
#    'last_observation_date': '2021-01-07',
#    'data_arc_in_days': 24088,
#    'observations_used': 4651,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.104589',
#    'jupiter_tisserand_invariant': '3.513',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5380832682708995',
#    'semi_major_axis': '1.893699210044564',
#    'inclination': '41.19928004878117',
#    'ascending_node_longitude': '63.49079619033483',
#    'orbital_period': '951.8421309886187',
#    'perihelion_distance': '.8747313499817644',
#    'perihelion_argument': '293.0630084560417',
#    'aphelion_distance': '2.912667070107363',
#    'perihelion_time': '2458725.035108259428',
#    'mean_anomaly': '104.1846728549483',
#    'mean_motion': '.378213979272057',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001915?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001915',
#   'neo_reference_id': '2001915',
#   'name': '1915 Quetzalcoatl (1953 EA)',
#   'name_limited': 'Quetzalcoatl',
#   'designation': '1915',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001915',
#   'absolute_magnitude_h': 18.97,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4271249851,
#     'estimated_diameter_max': 0.9550805015},
#    'meters': {'estimated_diameter_min': 427.1249850508,
#     'estimated_diameter_max': 955.0805014622},
#    'miles': {'estimated_diameter_min': 0.2654030791,
#     'estimated_diameter_max': 0.5934593263},
#    'feet': {'estimated_diameter_min': 1401.3287359541,
#     'estimated_diameter_max': 3133.4663124173}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '11',
#    'orbit_determination_date': '2017-04-06 09:30:52',
#    'first_observation_date': '1953-03-09',
#    'last_observation_date': '2004-10-09',
#    'data_arc_in_days': 18842,
#    'observations_used': 51,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.10802',
#    'jupiter_tisserand_invariant': '3.122',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5705651799672322',
#    'semi_major_axis': '2.543415980989979',
#    'inclination': '20.40461297143561',
#    'ascending_node_longitude': '162.9367848834301',
#    'orbital_period': '1481.577999888293',
#    'perihelion_distance': '1.092231384064897',
#    'perihelion_argument': '347.8324357485029',
#    'aphelion_distance': '3.994600577915061',
#    'perihelion_time': '2459430.184363860847',
#    'mean_anomaly': '255.5935016573088',
#    'mean_motion': '.2429841695996721',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001916?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001916',
#   'neo_reference_id': '2001916',
#   'name': '1916 Boreas (1953 RA)',
#   'name_limited': 'Boreas',
#   'designation': '1916',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001916',
#   'absolute_magnitude_h': 14.8,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 2.9144390453,
#     'estimated_diameter_max': 6.5168838217},
#    'meters': {'estimated_diameter_min': 2914.4390453486,
#     'estimated_diameter_max': 6516.883821679},
#    'miles': {'estimated_diameter_min': 1.810947904,
#     'estimated_diameter_max': 4.0494026172},
#    'feet': {'estimated_diameter_min': 9561.8081975415,
#     'estimated_diameter_max': 21380.8531175174}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '262',
#    'orbit_determination_date': '2020-12-22 05:51:25',
#    'first_observation_date': '1953-09-01',
#    'last_observation_date': '2020-12-21',
#    'data_arc_in_days': 24583,
#    'observations_used': 1582,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.252842',
#    'jupiter_tisserand_invariant': '3.440',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.4496411674359826',
#    'semi_major_axis': '2.273086560377827',
#    'inclination': '12.88010266119852',
#    'ascending_node_longitude': '340.5990723685613',
#    'orbital_period': '1251.763800673823',
#    'perihelion_distance': '1.251013265686499',
#    'perihelion_argument': '335.8670313690499',
#    'aphelion_distance': '3.295159855069155',
#    'perihelion_time': '2458375.667399208105',
#    'mean_anomaly': '179.6982275442039',
#    'mean_motion': '.2875941929349709',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001917?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001917',
#   'neo_reference_id': '2001917',
#   'name': '1917 Cuyo (1968 AA)',
#   'name_limited': 'Cuyo',
#   'designation': '1917',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001917',
#   'absolute_magnitude_h': 14.3,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 3.6690613753,
#     'estimated_diameter_max': 8.2042706488},
#    'meters': {'estimated_diameter_min': 3669.0613753145,
#     'estimated_diameter_max': 8204.270648822},
#    'miles': {'estimated_diameter_min': 2.2798483358,
#     'estimated_diameter_max': 5.0978958573},
#    'feet': {'estimated_diameter_min': 12037.6033225867,
#     'estimated_diameter_max': 26916.8993154812}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '465',
#    'orbit_determination_date': '2020-10-01 06:39:15',
#    'first_observation_date': '1954-05-06',
#    'last_observation_date': '2020-09-26',
#    'data_arc_in_days': 24250,
#    'observations_used': 2349,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.0727329',
#    'jupiter_tisserand_invariant': '3.435',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5055075486188304',
#    'semi_major_axis': '2.149076811635364',
#    'inclination': '23.95916227254964',
#    'ascending_node_longitude': '188.3070349840897',
#    'orbital_period': '1150.737680511229',
#    'perihelion_distance': '1.062702260791999',
#    'perihelion_argument': '194.5059486453876',
#    'aphelion_distance': '3.235451362478729',
#    'perihelion_time': '2459337.337861606959',
#    'mean_anomaly': '254.6226996541615',
#    'mean_motion': '.3128428017061766',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001943?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001943',
#   'neo_reference_id': '2001943',
#   'name': '1943 Anteros (1973 EC)',
#   'name_limited': 'Anteros',
#   'designation': '1943',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001943',
#   'absolute_magnitude_h': 15.6,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 2.0162991944,
#     'estimated_diameter_max': 4.5085820617},
#    'meters': {'estimated_diameter_min': 2016.2991944276,
#     'estimated_diameter_max': 4508.5820617181},
#    'miles': {'estimated_diameter_min': 1.2528698467,
#     'estimated_diameter_max': 2.8015021443},
#    'feet': {'estimated_diameter_min': 6615.1550490457,
#     'estimated_diameter_max': 14791.9363713673}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '535',
#    'orbit_determination_date': '2021-01-30 06:46:51',
#    'first_observation_date': '1973-03-10',
#    'last_observation_date': '2021-01-29',
#    'data_arc_in_days': 17492,
#    'observations_used': 3656,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.0623068',
#    'jupiter_tisserand_invariant': '4.640',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.2559951675549342',
#    'semi_major_axis': '1.430462184162156',
#    'inclination': '8.706204864760755',
#    'ascending_node_longitude': '246.3297681522486',
#    'orbital_period': '624.90355990637',
#    'perihelion_distance': '1.064270777646568',
#    'perihelion_argument': '338.373969686559',
#    'aphelion_distance': '1.796653590677745',
#    'perihelion_time': '2459298.654011511991',
#    'mean_anomaly': '188.2367855923257',
#    'mean_motion': '.5760888929068338',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2001980?api_key=hOZOTqvmufgVTM2RL3oJasWyHyXWGBcF5gSLffqJ'},
#   'id': '2001980',
#   'neo_reference_id': '2001980',
#   'name': '1980 Tezcatlipoca (1950 LA)',
#   'name_limited': 'Tezcatlipoca',
#   'designation': '1980',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001980',
#   'absolute_magnitude_h': 13.8,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 4.6190746028,
#     'estimated_diameter_max': 10.328564805},
#    'meters': {'estimated_diameter_min': 4619.0746028158,
#     'estimated_diameter_max': 10328.5648050391},
#    'miles': {'estimated_diameter_min': 2.870159005,
#     'estimated_diameter_max': 6.4178706415},
#    'feet': {'estimated_diameter_min': 15154.4447199023,
#     'estimated_diameter_max': 33886.3685549643}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '537',
#    'orbit_determination_date': '2021-01-22 05:18:38',
#    'first_observation_date': '1950-06-19',
#    'last_observation_date': '2021-01-21',
#    'data_arc_in_days': 25784,
#    'observations_used': 3525,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.245963',
#    'jupiter_tisserand_invariant': '3.996',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.3645634489721971',
#    'semi_major_axis': '1.709577917576679',
#    'inclination': '26.86722470137853',
#    'ascending_node_longitude': '246.573370502069',
#    'orbital_period': '816.4541033430276',
#    'perihelion_distance': '1.086328295658218',
#    'perihelion_argument': '115.4449630799087',
#    'aphelion_distance': '2.332827539495139',
#    'perihelion_time': '2458888.014989066058',
#    'mean_anomaly': '49.59813879360888',
#    'mean_motion': '.4409310927900971',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False}]

# %%
len(near_earth_objects[0].keys())
# Out:
# 13

# %%
near_earth_objects[0].keys()
# Out:
# dict_keys(['links', 'id', 'neo_reference_id', 'name', 'name_limited', 'designation', 'nasa_jpl_url', 'absolute_magnitude_h', 'estimated_diameter', 'is_potentially_hazardous_asteroid', 'close_approach_data', 'orbital_data', 'is_sentry_object'])

# %%
data = pd.DataFrame(near_earth_objects)
data
# Out:
#                                                 links       id  \
# 0   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000433
# 1   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000719
# 2   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000887
# 3   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001036
# 4   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001221
# 5   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001566
# 6   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001580
# 7   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001620
# 8   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001627
# 9   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001685
# 10  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001862
# 11  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001863
# 12  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001864
# 13  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001865
# 14  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001866
# 15  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001915
# 16  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001916
# 17  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001917
# 18  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001943
# 19  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001980
#
#    neo_reference_id                         name  name_limited designation  \
# 0           2000433           433 Eros (A898 PA)          Eros         433
# 1           2000719         719 Albert (A911 TB)        Albert         719
# 2           2000887         887 Alinda (A918 AA)        Alinda         887
# 3           2001036       1036 Ganymed (A924 UB)       Ganymed        1036
# 4           2001221         1221 Amor (1932 EA1)          Amor        1221
# 5           2001566        1566 Icarus (1949 MA)        Icarus        1566
# 6           2001580       1580 Betulia (1950 KA)       Betulia        1580
# 7           2001620    1620 Geographos (1951 RA)    Geographos        1620
# 8           2001627          1627 Ivar (1929 SH)          Ivar        1627
# 9           2001685          1685 Toro (1948 OA)          Toro        1685
# 10          2001862        1862 Apollo (1932 HA)        Apollo        1862
# 11          2001863      1863 Antinous (1948 EA)      Antinous        1863
# 12          2001864      1864 Daedalus (1971 FA)      Daedalus        1864
# 13          2001865      1865 Cerberus (1971 UA)      Cerberus        1865
# 14          2001866      1866 Sisyphus (1972 XA)      Sisyphus        1866
# 15          2001915  1915 Quetzalcoatl (1953 EA)  Quetzalcoatl        1915
# 16          2001916        1916 Boreas (1953 RA)        Boreas        1916
# 17          2001917          1917 Cuyo (1968 AA)          Cuyo        1917
# 18          2001943       1943 Anteros (1973 EC)       Anteros        1943
# 19          2001980  1980 Tezcatlipoca (1950 LA)  Tezcatlipoca        1980
#
#                                      nasa_jpl_url  absolute_magnitude_h  \
# 0   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                 10.40
# 1   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                 15.50
# 2   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                 13.80
# 3   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                  9.40
# 4   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                 17.70
# 5   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001566                 16.90
# 6   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001580                 14.70
# 7   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001620                 15.30
# 8   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001627                 12.70
# 9   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001685                 14.30
# 10  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001862                 16.25
# 11  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001863                 15.30
# 12  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001864                 14.70
# 13  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001865                 16.70
# 14  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001866                 12.40
# 15  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001915                 18.97
# 16  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001916                 14.80
# 17  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001917                 14.30
# 18  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001943                 15.60
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001980                 13.80
#
#                                    estimated_diameter  \
# 0   {'kilometers': {'estimated_diameter_min': 22.1...
# 1   {'kilometers': {'estimated_diameter_min': 2.11...
# 2   {'kilometers': {'estimated_diameter_min': 4.61...
# 3   {'kilometers': {'estimated_diameter_min': 35.0...
# 4   {'kilometers': {'estimated_diameter_min': 0.76...
# 5   {'kilometers': {'estimated_diameter_min': 1.10...
# 6   {'kilometers': {'estimated_diameter_min': 3.05...
# 7   {'kilometers': {'estimated_diameter_min': 2.31...
# 8   {'kilometers': {'estimated_diameter_min': 7.66...
# 9   {'kilometers': {'estimated_diameter_min': 3.66...
# 10  {'kilometers': {'estimated_diameter_min': 1.49...
# 11  {'kilometers': {'estimated_diameter_min': 2.31...
# 12  {'kilometers': {'estimated_diameter_min': 3.05...
# 13  {'kilometers': {'estimated_diameter_min': 1.21...
# 14  {'kilometers': {'estimated_diameter_min': 8.80...
# 15  {'kilometers': {'estimated_diameter_min': 0.42...
# 16  {'kilometers': {'estimated_diameter_min': 2.91...
# 17  {'kilometers': {'estimated_diameter_min': 3.66...
# 18  {'kilometers': {'estimated_diameter_min': 2.01...
# 19  {'kilometers': {'estimated_diameter_min': 4.61...
#
#     is_potentially_hazardous_asteroid close_approach_data  \
# 0                               False                  []
# 1                               False                  []
# 2                               False                  []
# 3                               False                  []
# 4                               False                  []
# 5                                True                  []
# 6                               False                  []
# 7                                True                  []
# 8                               False                  []
# 9                               False                  []
# 10                               True                  []
# 11                              False                  []
# 12                              False                  []
# 13                              False                  []
# 14                              False                  []
# 15                              False                  []
# 16                              False                  []
# 17                              False                  []
# 18                              False                  []
# 19                              False                  []
#
#                                          orbital_data  is_sentry_object
# 0   {'orbit_id': '658', 'orbit_determination_date'...             False
# 1   {'orbit_id': '215', 'orbit_determination_date'...             False
# 2   {'orbit_id': '343', 'orbit_determination_date'...             False
# 3   {'orbit_id': '863', 'orbit_determination_date'...             False
# 4   {'orbit_id': '104', 'orbit_determination_date'...             False
# 5   {'orbit_id': '119', 'orbit_determination_date'...             False
# 6   {'orbit_id': '257', 'orbit_determination_date'...             False
# 7   {'orbit_id': '610', 'orbit_determination_date'...             False
# 8   {'orbit_id': '1011', 'orbit_determination_date...             False
# 9   {'orbit_id': '538', 'orbit_determination_date'...             False
# 10  {'orbit_id': '313', 'orbit_determination_date'...             False
# 11  {'orbit_id': '198', 'orbit_determination_date'...             False
# 12  {'orbit_id': '543', 'orbit_determination_date'...             False
# 13  {'orbit_id': '345', 'orbit_determination_date'...             False
# 14  {'orbit_id': '723', 'orbit_determination_date'...             False
# 15  {'orbit_id': '11', 'orbit_determination_date':...             False
# 16  {'orbit_id': '262', 'orbit_determination_date'...             False
# 17  {'orbit_id': '465', 'orbit_determination_date'...             False
# 18  {'orbit_id': '535', 'orbit_determination_date'...             False
# 19  {'orbit_id': '537', 'orbit_determination_date'...             False

# %%
def flatten(data, cols):
    for c in cols:
        fl = pd.DataFrame(dict(data[c])).T
        cols = [str(col) for col in fl.columns]
        fl.columns = [c+''+name for name in cols]
        data = pd.concat([data,fl], axis = 1)
        data = data.drop(c, axis = 1)
    return data

# %%
data = flatten(data, ['orbital_data'])
data.head()
# Out:
#                                                links       id  \
# 0  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000433
# 1  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000719
# 2  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000887
# 3  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001036
# 4  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001221
#
#   neo_reference_id                    name name_limited designation  \
# 0          2000433      433 Eros (A898 PA)         Eros         433
# 1          2000719    719 Albert (A911 TB)       Albert         719
# 2          2000887    887 Alinda (A918 AA)       Alinda         887
# 3          2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4          2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#                                   estimated_diameter  \
# 0  {'kilometers': {'estimated_diameter_min': 22.1...
# 1  {'kilometers': {'estimated_diameter_min': 2.11...
# 2  {'kilometers': {'estimated_diameter_min': 4.61...
# 3  {'kilometers': {'estimated_diameter_min': 35.0...
# 4  {'kilometers': {'estimated_diameter_min': 0.76...
#
#    is_potentially_hazardous_asteroid  ...  \
# 0                              False  ...
# 1                              False  ...
# 2                              False  ...
# 3                              False  ...
# 4                              False  ...
#
#   orbital_dataascending_node_longitude  orbital_dataorbital_period  \
# 0                    304.2993259000444           643.0654021001488
# 1                      183.86694755492           1565.522355420405
# 2                     110.434243296083           1421.113270604532
# 3                    215.5468281945239           1588.828164013753
# 4                    171.3270121727965           971.3594594940868
#
#   orbital_dataperihelion_distance orbital_dataperihelion_argument  \
# 0               1.132972589728666               178.8822959227224
# 1               1.196451767907194                156.176340057815
# 2               1.062886296374618               350.4955520605819
# 3               1.244303491543309               132.3646330593546
# 4               1.083969486367978               26.69478755345107
#
#   orbital_dataaphelion_distance orbital_dataperihelion_time  \
# 0             1.783118868433408        2459159.351922368362
# 1             4.080752360532158        2458390.496728247930
# 2             3.884587557390264        2459258.751134668900
# 3             4.085145756961542        2458979.237312304403
# 4             2.755026814657094        2458896.558033524650
#
#   orbital_datamean_anomaly orbital_datamean_motion orbital_dataequinox  \
# 0        271.0717325705167       .5598186418120109               J2000
# 1        140.2734218840163       .2299551959469309               J2000
# 2        294.5791708487424       .2533225235781933               J2000
# 3        4.817744136079234       .2265820861902117               J2000
# 4        38.52241059207368       .3706146025360157               J2000
#
#                              orbital_dataorbit_class
# 0  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 1  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 2  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 3  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 4  {'orbit_class_type': 'AMO', 'orbit_class_descr...
#
# [5 rows x 35 columns]

# %%
df2 = data.copy()
df2.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 35 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   links                                    20 non-null     object
#  1   id                                       20 non-null     object
#  2   neo_reference_id                         20 non-null     object
#  3   name                                     20 non-null     object
#  4   name_limited                             20 non-null     object
#  5   designation                              20 non-null     object
#  6   nasa_jpl_url                             20 non-null     object
#  7   absolute_magnitude_h                     20 non-null     float64
#  8   estimated_diameter                       20 non-null     object
#  9   is_potentially_hazardous_asteroid        20 non-null     bool
#  10  close_approach_data                      20 non-null     object
#  11  is_sentry_object                         20 non-null     bool
#  12  orbital_dataorbit_id                     20 non-null     object
#  13  orbital_dataorbit_determination_date     20 non-null     object
#  14  orbital_datafirst_observation_date       20 non-null     object
#  15  orbital_datalast_observation_date        20 non-null     object
#  16  orbital_datadata_arc_in_days             20 non-null     object
#  17  orbital_dataobservations_used            20 non-null     object
#  18  orbital_dataorbit_uncertainty            20 non-null     object
#  19  orbital_dataminimum_orbit_intersection   20 non-null     object
#  20  orbital_datajupiter_tisserand_invariant  20 non-null     object
#  21  orbital_dataepoch_osculation             20 non-null     object
#  22  orbital_dataeccentricity                 20 non-null     object
#  23  orbital_datasemi_major_axis              20 non-null     object
#  24  orbital_datainclination                  20 non-null     object
#  25  orbital_dataascending_node_longitude     20 non-null     object
#  26  orbital_dataorbital_period               20 non-null     object
#  27  orbital_dataperihelion_distance          20 non-null     object
#  28  orbital_dataperihelion_argument          20 non-null     object
#  29  orbital_dataaphelion_distance            20 non-null     object
#  30  orbital_dataperihelion_time              20 non-null     object
#  31  orbital_datamean_anomaly                 20 non-null     object
#  32  orbital_datamean_motion                  20 non-null     object
#  33  orbital_dataequinox                      20 non-null     object
#  34  orbital_dataorbit_class                  20 non-null     object
# dtypes: bool(2), float64(1), object(32)
# memory usage: 5.3+ KB

# %%
df2.head()
# Out:
#                                                links       id  \
# 0  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000433
# 1  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000719
# 2  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2000887
# 3  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001036
# 4  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  2001221
#
#   neo_reference_id                    name name_limited designation  \
# 0          2000433      433 Eros (A898 PA)         Eros         433
# 1          2000719    719 Albert (A911 TB)       Albert         719
# 2          2000887    887 Alinda (A918 AA)       Alinda         887
# 3          2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4          2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#                                   estimated_diameter  \
# 0  {'kilometers': {'estimated_diameter_min': 22.1...
# 1  {'kilometers': {'estimated_diameter_min': 2.11...
# 2  {'kilometers': {'estimated_diameter_min': 4.61...
# 3  {'kilometers': {'estimated_diameter_min': 35.0...
# 4  {'kilometers': {'estimated_diameter_min': 0.76...
#
#    is_potentially_hazardous_asteroid  ...  \
# 0                              False  ...
# 1                              False  ...
# 2                              False  ...
# 3                              False  ...
# 4                              False  ...
#
#   orbital_dataascending_node_longitude  orbital_dataorbital_period  \
# 0                    304.2993259000444           643.0654021001488
# 1                      183.86694755492           1565.522355420405
# 2                     110.434243296083           1421.113270604532
# 3                    215.5468281945239           1588.828164013753
# 4                    171.3270121727965           971.3594594940868
#
#   orbital_dataperihelion_distance orbital_dataperihelion_argument  \
# 0               1.132972589728666               178.8822959227224
# 1               1.196451767907194                156.176340057815
# 2               1.062886296374618               350.4955520605819
# 3               1.244303491543309               132.3646330593546
# 4               1.083969486367978               26.69478755345107
#
#   orbital_dataaphelion_distance orbital_dataperihelion_time  \
# 0             1.783118868433408        2459159.351922368362
# 1             4.080752360532158        2458390.496728247930
# 2             3.884587557390264        2459258.751134668900
# 3             4.085145756961542        2458979.237312304403
# 4             2.755026814657094        2458896.558033524650
#
#   orbital_datamean_anomaly orbital_datamean_motion orbital_dataequinox  \
# 0        271.0717325705167       .5598186418120109               J2000
# 1        140.2734218840163       .2299551959469309               J2000
# 2        294.5791708487424       .2533225235781933               J2000
# 3        4.817744136079234       .2265820861902117               J2000
# 4        38.52241059207368       .3706146025360157               J2000
#
#                              orbital_dataorbit_class
# 0  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 1  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 2  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 3  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 4  {'orbit_class_type': 'AMO', 'orbit_class_descr...
#
# [5 rows x 35 columns]

# %%
df2 = flatten(df2, ['estimated_diameter'])

# %%
df2.drop(['links', 'neo_reference_id'], axis = 1, inplace = True)

# %%
df2.head()
# Out:
#         id                    name name_limited designation  \
# 0  2000433      433 Eros (A898 PA)         Eros         433
# 1  2000719    719 Albert (A911 TB)       Albert         719
# 2  2000887    887 Alinda (A918 AA)       Alinda         887
# 3  2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4  2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#    is_potentially_hazardous_asteroid close_approach_data  is_sentry_object  \
# 0                              False                  []             False
# 1                              False                  []             False
# 2                              False                  []             False
# 3                              False                  []             False
# 4                              False                  []             False
#
#   orbital_dataorbit_id  ... orbital_dataaphelion_distance  \
# 0                  658  ...             1.783118868433408
# 1                  215  ...             4.080752360532158
# 2                  343  ...             3.884587557390264
# 3                  863  ...             4.085145756961542
# 4                  104  ...             2.755026814657094
#
#   orbital_dataperihelion_time orbital_datamean_anomaly  \
# 0        2459159.351922368362        271.0717325705167
# 1        2458390.496728247930        140.2734218840163
# 2        2459258.751134668900        294.5791708487424
# 3        2458979.237312304403        4.817744136079234
# 4        2458896.558033524650        38.52241059207368
#
#   orbital_datamean_motion orbital_dataequinox  \
# 0       .5598186418120109               J2000
# 1       .2299551959469309               J2000
# 2       .2533225235781933               J2000
# 3       .2265820861902117               J2000
# 4       .3706146025360157               J2000
#
#                              orbital_dataorbit_class  \
# 0  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 1  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 2  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 3  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 4  {'orbit_class_type': 'AMO', 'orbit_class_descr...
#
#                         estimated_diameterkilometers  \
# 0  {'estimated_diameter_min': 22.1082810359, 'est...
# 1  {'estimated_diameter_min': 2.1113244479, 'esti...
# 2  {'estimated_diameter_min': 4.6190746028, 'esti...
# 3  {'estimated_diameter_min': 35.0392641108, 'est...
# 4  {'estimated_diameter_min': 0.7665755735, 'esti...
#
#                             estimated_diametermeters  \
# 0  {'estimated_diameter_min': 22108.281035909, 'e...
# 1  {'estimated_diameter_min': 2111.3244478971, 'e...
# 2  {'estimated_diameter_min': 4619.0746028158, 'e...
# 3  {'estimated_diameter_min': 35039.2641108293, '...
# 4  {'estimated_diameter_min': 766.5755735311, 'es...
#
#                              estimated_diametermiles  \
# 0  {'estimated_diameter_min': 13.7374446956, 'est...
# 1  {'estimated_diameter_min': 1.3119157835, 'esti...
# 2  {'estimated_diameter_min': 2.870159005, 'estim...
# 3  {'estimated_diameter_min': 21.7723825798, 'est...
# 4  {'estimated_diameter_min': 0.4763278307, 'esti...
#
#                               estimated_diameterfeet
# 0  {'estimated_diameter_min': 72533.7327538517, '...
# 1  {'estimated_diameter_min': 6926.9177016389, 'e...
# 2  {'estimated_diameter_min': 15154.4447199023, '...
# 3  {'estimated_diameter_min': 114958.2192653732, ...
# 4  {'estimated_diameter_min': 2515.0118046636, 'e...
#
# [5 rows x 36 columns]

# %%
df2.drop(['estimated_diametermeters', 'estimated_diametermiles', 'estimated_diameterfeet'], axis = 1, inplace = True)

# %%
df2.head()
# Out:
#         id                    name name_limited designation  \
# 0  2000433      433 Eros (A898 PA)         Eros         433
# 1  2000719    719 Albert (A911 TB)       Albert         719
# 2  2000887    887 Alinda (A918 AA)       Alinda         887
# 3  2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4  2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#    is_potentially_hazardous_asteroid close_approach_data  is_sentry_object  \
# 0                              False                  []             False
# 1                              False                  []             False
# 2                              False                  []             False
# 3                              False                  []             False
# 4                              False                  []             False
#
#   orbital_dataorbit_id  ... orbital_dataorbital_period  \
# 0                  658  ...          643.0654021001488
# 1                  215  ...          1565.522355420405
# 2                  343  ...          1421.113270604532
# 3                  863  ...          1588.828164013753
# 4                  104  ...          971.3594594940868
#
#   orbital_dataperihelion_distance orbital_dataperihelion_argument  \
# 0               1.132972589728666               178.8822959227224
# 1               1.196451767907194                156.176340057815
# 2               1.062886296374618               350.4955520605819
# 3               1.244303491543309               132.3646330593546
# 4               1.083969486367978               26.69478755345107
#
#   orbital_dataaphelion_distance orbital_dataperihelion_time  \
# 0             1.783118868433408        2459159.351922368362
# 1             4.080752360532158        2458390.496728247930
# 2             3.884587557390264        2459258.751134668900
# 3             4.085145756961542        2458979.237312304403
# 4             2.755026814657094        2458896.558033524650
#
#   orbital_datamean_anomaly orbital_datamean_motion orbital_dataequinox  \
# 0        271.0717325705167       .5598186418120109               J2000
# 1        140.2734218840163       .2299551959469309               J2000
# 2        294.5791708487424       .2533225235781933               J2000
# 3        4.817744136079234       .2265820861902117               J2000
# 4        38.52241059207368       .3706146025360157               J2000
#
#                              orbital_dataorbit_class  \
# 0  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 1  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 2  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 3  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 4  {'orbit_class_type': 'AMO', 'orbit_class_descr...
#
#                         estimated_diameterkilometers
# 0  {'estimated_diameter_min': 22.1082810359, 'est...
# 1  {'estimated_diameter_min': 2.1113244479, 'esti...
# 2  {'estimated_diameter_min': 4.6190746028, 'esti...
# 3  {'estimated_diameter_min': 35.0392641108, 'est...
# 4  {'estimated_diameter_min': 0.7665755735, 'esti...
#
# [5 rows x 33 columns]

# %%
df2.drop(['orbital_dataorbit_id', 'orbital_dataorbital_period', 'orbital_dataperihelion_distance', 'orbital_dataperihelion_argument', 'orbital_dataaphelion_distance', 'orbital_dataperihelion_time', 'orbital_datamean_anomaly', 'orbital_datamean_motion', 'orbital_dataequinox'] , axis = 1, inplace = True)

# %%
df2.head()
# Out:
#         id                    name name_limited designation  \
# 0  2000433      433 Eros (A898 PA)         Eros         433
# 1  2000719    719 Albert (A911 TB)       Albert         719
# 2  2000887    887 Alinda (A918 AA)       Alinda         887
# 3  2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4  2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#    is_potentially_hazardous_asteroid close_approach_data  is_sentry_object  \
# 0                              False                  []             False
# 1                              False                  []             False
# 2                              False                  []             False
# 3                              False                  []             False
# 4                              False                  []             False
#
#   orbital_dataorbit_determination_date  ... orbital_dataorbit_uncertainty  \
# 0                  2020-09-06 18:22:27  ...                             0
# 1                  2020-12-24 05:55:26  ...                             0
# 2                  2021-01-31 06:47:13  ...                             0
# 3                  2021-01-31 06:47:13  ...                             0
# 4                  2020-11-21 05:21:26  ...                             0
#
#   orbital_dataminimum_orbit_intersection  \
# 0                                .148623
# 1                                .203482
# 2                                .082217
# 3                                .344956
# 4                                 .10745
#
#   orbital_datajupiter_tisserand_invariant orbital_dataepoch_osculation  \
# 0                                   4.582                    2459000.5
# 1                                   3.140                    2459000.5
# 2                                   3.221                    2459000.5
# 3                                   3.035                    2459000.5
# 4                                   3.781                    2459000.5
#
#   orbital_dataeccentricity orbital_datasemi_major_axis  \
# 0        .2229512647434284           1.458045729081037
# 1        .5465584658893893           2.638602064219676
# 2        .5703317176438265           2.473736926882441
# 3        .5330461240840629           2.664724624252425
# 4          .43528495399772           1.919498150512536
#
#   orbital_datainclination orbital_dataascending_node_longitude  \
# 0       10.83054121829922                    304.2993259000444
# 1       11.56748450944226                      183.86694755492
# 2       9.393850619707097                     110.434243296083
# 3       26.67764044274185                    215.5468281945239
# 4       11.87653980721408                    171.3270121727965
#
#                              orbital_dataorbit_class  \
# 0  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 1  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 2  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 3  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 4  {'orbit_class_type': 'AMO', 'orbit_class_descr...
#
#                         estimated_diameterkilometers
# 0  {'estimated_diameter_min': 22.1082810359, 'est...
# 1  {'estimated_diameter_min': 2.1113244479, 'esti...
# 2  {'estimated_diameter_min': 4.6190746028, 'esti...
# 3  {'estimated_diameter_min': 35.0392641108, 'est...
# 4  {'estimated_diameter_min': 0.7665755735, 'esti...
#
# [5 rows x 24 columns]

# %%
df2.drop(['orbital_dataorbit_uncertainty', 'orbital_dataminimum_orbit_intersection', 'orbital_datajupiter_tisserand_invariant', 'orbital_dataepoch_osculation', 'orbital_dataeccentricity', 'orbital_datasemi_major_axis', 'orbital_dataascending_node_longitude'] , axis = 1, inplace = True)
df2.head()
# Out:
#         id                    name name_limited designation  \
# 0  2000433      433 Eros (A898 PA)         Eros         433
# 1  2000719    719 Albert (A911 TB)       Albert         719
# 2  2000887    887 Alinda (A918 AA)       Alinda         887
# 3  2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4  2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#    is_potentially_hazardous_asteroid close_approach_data  is_sentry_object  \
# 0                              False                  []             False
# 1                              False                  []             False
# 2                              False                  []             False
# 3                              False                  []             False
# 4                              False                  []             False
#
#   orbital_dataorbit_determination_date orbital_datafirst_observation_date  \
# 0                  2020-09-06 18:22:27                         1893-10-29
# 1                  2020-12-24 05:55:26                         1911-10-04
# 2                  2021-01-31 06:47:13                         1918-02-03
# 3                  2021-01-31 06:47:13                         1924-10-23
# 4                  2020-11-21 05:21:26                         1932-03-12
#
#   orbital_datalast_observation_date orbital_datadata_arc_in_days  \
# 0                        2020-09-03                        46330
# 1                        2020-12-23                        39893
# 2                        2021-01-30                        37617
# 3                        2021-01-30                        35163
# 4                        2020-09-14                        32328
#
#   orbital_dataobservations_used orbital_datainclination  \
# 0                          8767       10.83054121829922
# 1                          1878       11.56748450944226
# 2                          2049       9.393850619707097
# 3                          6664       26.67764044274185
# 4                           552       11.87653980721408
#
#                              orbital_dataorbit_class  \
# 0  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 1  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 2  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 3  {'orbit_class_type': 'AMO', 'orbit_class_descr...
# 4  {'orbit_class_type': 'AMO', 'orbit_class_descr...
#
#                         estimated_diameterkilometers
# 0  {'estimated_diameter_min': 22.1082810359, 'est...
# 1  {'estimated_diameter_min': 2.1113244479, 'esti...
# 2  {'estimated_diameter_min': 4.6190746028, 'esti...
# 3  {'estimated_diameter_min': 35.0392641108, 'est...
# 4  {'estimated_diameter_min': 0.7665755735, 'esti...

# %%
df2 = flatten(df2, ['orbital_dataorbit_class'])

# %%
df2 = flatten(df2, ['estimated_diameterkilometers'])

# %%
df2.head()
# Out:
#         id                    name name_limited designation  \
# 0  2000433      433 Eros (A898 PA)         Eros         433
# 1  2000719    719 Albert (A911 TB)       Albert         719
# 2  2000887    887 Alinda (A918 AA)       Alinda         887
# 3  2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4  2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#    is_potentially_hazardous_asteroid close_approach_data  is_sentry_object  \
# 0                              False                  []             False
# 1                              False                  []             False
# 2                              False                  []             False
# 3                              False                  []             False
# 4                              False                  []             False
#
#   orbital_dataorbit_determination_date orbital_datafirst_observation_date  \
# 0                  2020-09-06 18:22:27                         1893-10-29
# 1                  2020-12-24 05:55:26                         1911-10-04
# 2                  2021-01-31 06:47:13                         1918-02-03
# 3                  2021-01-31 06:47:13                         1924-10-23
# 4                  2020-11-21 05:21:26                         1932-03-12
#
#   orbital_datalast_observation_date orbital_datadata_arc_in_days  \
# 0                        2020-09-03                        46330
# 1                        2020-12-23                        39893
# 2                        2021-01-30                        37617
# 3                        2021-01-30                        35163
# 4                        2020-09-14                        32328
#
#   orbital_dataobservations_used orbital_datainclination  \
# 0                          8767       10.83054121829922
# 1                          1878       11.56748450944226
# 2                          2049       9.393850619707097
# 3                          6664       26.67764044274185
# 4                           552       11.87653980721408
#
#   orbital_dataorbit_classorbit_class_type  \
# 0                                     AMO
# 1                                     AMO
# 2                                     AMO
# 3                                     AMO
# 4                                     AMO
#
#       orbital_dataorbit_classorbit_class_description  \
# 0  Near-Earth asteroid orbits similar to that of ...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits similar to that of ...
# 3  Near-Earth asteroid orbits similar to that of ...
# 4  Near-Earth asteroid orbits similar to that of ...
#
#   orbital_dataorbit_classorbit_class_range  \
# 0       1.017 AU < q (perihelion) < 1.3 AU
# 1       1.017 AU < q (perihelion) < 1.3 AU
# 2       1.017 AU < q (perihelion) < 1.3 AU
# 3       1.017 AU < q (perihelion) < 1.3 AU
# 4       1.017 AU < q (perihelion) < 1.3 AU
#
#    estimated_diameterkilometersestimated_diameter_min  \
# 0                                          22.108281
# 1                                           2.111324
# 2                                           4.619075
# 3                                          35.039264
# 4                                           0.766576
#
#    estimated_diameterkilometersestimated_diameter_max
# 0                                          49.435619
# 1                                           4.721065
# 2                                          10.328565
# 3                                          78.350176
# 4                                           1.714115

# %%
df2.drop(['name', 'orbital_dataorbit_determination_date','orbital_datadata_arc_in_days', 
          'orbital_dataorbit_classorbit_class_range'] , axis = 1, inplace = True)
df2
# Out:
#          id  name_limited designation  \
# 0   2000433          Eros         433
# 1   2000719        Albert         719
# 2   2000887        Alinda         887
# 3   2001036       Ganymed        1036
# 4   2001221          Amor        1221
# 5   2001566        Icarus        1566
# 6   2001580       Betulia        1580
# 7   2001620    Geographos        1620
# 8   2001627          Ivar        1627
# 9   2001685          Toro        1685
# 10  2001862        Apollo        1862
# 11  2001863      Antinous        1863
# 12  2001864      Daedalus        1864
# 13  2001865      Cerberus        1865
# 14  2001866      Sisyphus        1866
# 15  2001915  Quetzalcoatl        1915
# 16  2001916        Boreas        1916
# 17  2001917          Cuyo        1917
# 18  2001943       Anteros        1943
# 19  2001980  Tezcatlipoca        1980
#
#                                      nasa_jpl_url  absolute_magnitude_h  \
# 0   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                 10.40
# 1   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                 15.50
# 2   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                 13.80
# 3   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                  9.40
# 4   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                 17.70
# 5   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001566                 16.90
# 6   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001580                 14.70
# 7   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001620                 15.30
# 8   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001627                 12.70
# 9   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001685                 14.30
# 10  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001862                 16.25
# 11  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001863                 15.30
# 12  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001864                 14.70
# 13  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001865                 16.70
# 14  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001866                 12.40
# 15  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001915                 18.97
# 16  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001916                 14.80
# 17  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001917                 14.30
# 18  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001943                 15.60
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001980                 13.80
#
#     is_potentially_hazardous_asteroid close_approach_data  is_sentry_object  \
# 0                               False                  []             False
# 1                               False                  []             False
# 2                               False                  []             False
# 3                               False                  []             False
# 4                               False                  []             False
# 5                                True                  []             False
# 6                               False                  []             False
# 7                                True                  []             False
# 8                               False                  []             False
# 9                               False                  []             False
# 10                               True                  []             False
# 11                              False                  []             False
# 12                              False                  []             False
# 13                              False                  []             False
# 14                              False                  []             False
# 15                              False                  []             False
# 16                              False                  []             False
# 17                              False                  []             False
# 18                              False                  []             False
# 19                              False                  []             False
#
#    orbital_datafirst_observation_date orbital_datalast_observation_date  \
# 0                          1893-10-29                        2020-09-03
# 1                          1911-10-04                        2020-12-23
# 2                          1918-02-03                        2021-01-30
# 3                          1924-10-23                        2021-01-30
# 4                          1932-03-12                        2020-09-14
# 5                          1949-07-01                        2020-09-08
# 6                          1950-05-22                        2021-01-18
# 7                          1951-08-31                        2020-04-17
# 8                          1929-09-25                        2020-06-22
# 9                          1948-07-17                        2021-01-29
# 10                         1930-12-13                        2021-01-19
# 11                         1948-03-05                        2021-01-16
# 12                         1971-03-24                        2020-06-12
# 13                         1971-10-26                        2021-01-12
# 14                         1955-01-26                        2021-01-07
# 15                         1953-03-09                        2004-10-09
# 16                         1953-09-01                        2020-12-21
# 17                         1954-05-06                        2020-09-26
# 18                         1973-03-10                        2021-01-29
# 19                         1950-06-19                        2021-01-21
#
#    orbital_dataobservations_used orbital_datainclination  \
# 0                           8767       10.83054121829922
# 1                           1878       11.56748450944226
# 2                           2049       9.393850619707097
# 3                           6664       26.67764044274185
# 4                            552       11.87653980721408
# 5                           1052       22.82210584381254
# 6                           1334       52.09207131550431
# 7                           4805       13.33704335138623
# 8                           7298       8.451869889021321
# 9                           3244       9.383132393569714
# 10                          1712       6.354730724437444
# 11                          1044       18.40043382088493
# 12                          2557        22.2119602234901
# 13                          1996       16.09595516619598
# 14                          4651       41.19928004878117
# 15                            51       20.40461297143561
# 16                          1582       12.88010266119852
# 17                          2349       23.95916227254964
# 18                          3656       8.706204864760755
# 19                          3525       26.86722470137853
#
#    orbital_dataorbit_classorbit_class_type  \
# 0                                      AMO
# 1                                      AMO
# 2                                      AMO
# 3                                      AMO
# 4                                      AMO
# 5                                      APO
# 6                                      AMO
# 7                                      APO
# 8                                      AMO
# 9                                      APO
# 10                                     APO
# 11                                     APO
# 12                                     APO
# 13                                     APO
# 14                                     APO
# 15                                     AMO
# 16                                     AMO
# 17                                     AMO
# 18                                     AMO
# 19                                     AMO
#
#        orbital_dataorbit_classorbit_class_description  \
# 0   Near-Earth asteroid orbits similar to that of ...
# 1   Near-Earth asteroid orbits similar to that of ...
# 2   Near-Earth asteroid orbits similar to that of ...
# 3   Near-Earth asteroid orbits similar to that of ...
# 4   Near-Earth asteroid orbits similar to that of ...
# 5   Near-Earth asteroid orbits which cross the Ear...
# 6   Near-Earth asteroid orbits similar to that of ...
# 7   Near-Earth asteroid orbits which cross the Ear...
# 8   Near-Earth asteroid orbits similar to that of ...
# 9   Near-Earth asteroid orbits which cross the Ear...
# 10  Near-Earth asteroid orbits which cross the Ear...
# 11  Near-Earth asteroid orbits which cross the Ear...
# 12  Near-Earth asteroid orbits which cross the Ear...
# 13  Near-Earth asteroid orbits which cross the Ear...
# 14  Near-Earth asteroid orbits which cross the Ear...
# 15  Near-Earth asteroid orbits similar to that of ...
# 16  Near-Earth asteroid orbits similar to that of ...
# 17  Near-Earth asteroid orbits similar to that of ...
# 18  Near-Earth asteroid orbits similar to that of ...
# 19  Near-Earth asteroid orbits similar to that of ...
#
#     estimated_diameterkilometersestimated_diameter_min  \
# 0                                           22.108281
# 1                                            2.111324
# 2                                            4.619075
# 3                                           35.039264
# 4                                            0.766576
# 5                                            1.108039
# 6                                            3.051792
# 7                                            2.315021
# 8                                            7.665756
# 9                                            3.669061
# 10                                           1.494703
# 11                                           2.315021
# 12                                           3.051792
# 13                                           1.214940
# 14                                           8.801465
# 15                                           0.427125
# 16                                           2.914439
# 17                                           3.669061
# 18                                           2.016299
# 19                                           4.619075
#
#     estimated_diameterkilometersestimated_diameter_max
# 0                                           49.435619
# 1                                            4.721065
# 2                                           10.328565
# 3                                           78.350176
# 4                                            1.714115
# 5                                            2.477650
# 6                                            6.824015
# 7                                            5.176545
# 8                                           17.141151
# 9                                            8.204271
# 10                                           3.342258
# 11                                           5.176545
# 12                                           6.824015
# 13                                           2.716689
# 14                                          19.680675
# 15                                           0.955081
# 16                                           6.516884
# 17                                           8.204271
# 18                                           4.508582
# 19                                          10.328565

# %%
df2.rename(columns = {'name_limited':'name', 'nasa_jpl_url':'nasa_url', 'is_potentially_hazardous_asteroid':'dangerous',
                      'estimated_diameterkilometersestimated_diameter_min':'diameter_km_min',
                      'estimated_diameterkilometersestimated_diameter_max':'diameter_km_max',
                     'orbital_dataorbit_classorbit_class_type':'orbit class type'}, inplace = True)

# %%
df3 = df2.copy()

# %%
df3.drop(['close_approach_data'], axis = 1, inplace = True)

# %%
df3.head()
# Out:
#         id     name designation  \
# 0  2000433     Eros         433
# 1  2000719   Albert         719
# 2  2000887   Alinda         887
# 3  2001036  Ganymed        1036
# 4  2001221     Amor        1221
#
#                                         nasa_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                  10.4
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                  15.5
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                  13.8
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                   9.4
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                  17.7
#
#    dangerous  is_sentry_object orbital_datafirst_observation_date  \
# 0      False             False                         1893-10-29
# 1      False             False                         1911-10-04
# 2      False             False                         1918-02-03
# 3      False             False                         1924-10-23
# 4      False             False                         1932-03-12
#
#   orbital_datalast_observation_date orbital_dataobservations_used  \
# 0                        2020-09-03                          8767
# 1                        2020-12-23                          1878
# 2                        2021-01-30                          2049
# 3                        2021-01-30                          6664
# 4                        2020-09-14                           552
#
#   orbital_datainclination orbit class type  \
# 0       10.83054121829922              AMO
# 1       11.56748450944226              AMO
# 2       9.393850619707097              AMO
# 3       26.67764044274185              AMO
# 4       11.87653980721408              AMO
#
#       orbital_dataorbit_classorbit_class_description  diameter_km_min  \
# 0  Near-Earth asteroid orbits similar to that of ...        22.108281
# 1  Near-Earth asteroid orbits similar to that of ...         2.111324
# 2  Near-Earth asteroid orbits similar to that of ...         4.619075
# 3  Near-Earth asteroid orbits similar to that of ...        35.039264
# 4  Near-Earth asteroid orbits similar to that of ...         0.766576
#
#    diameter_km_max
# 0        49.435619
# 1         4.721065
# 2        10.328565
# 3        78.350176
# 4         1.714115

# %%
df3['dangerous'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='dangerous'>

# %%
df3.sort_values('orbital_dataobservations_used', ascending=False).head(10)['name']
# Out:
# 0             Eros
# 8             Ivar
# 3          Ganymed
# 7       Geographos
# 14        Sisyphus
# 18         Anteros
# 19    Tezcatlipoca
# 9             Toro
# 12        Daedalus
# 17            Cuyo
# Name: name, dtype: object

# %%
df3.to_csv('DataApi.csv')
