# %% [markdown]
# # Pandas Project Kathi Aparicio

# %%
import pandas as pd


df = pd.read_csv("attacks.csv",encoding='latin-1')
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
idx = df.index[df.isnull().all(1)]
nans = df.iloc[idx]
nans
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8703          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8704          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8705          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8706          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# ...

# %%
#se quiere elimar todas las filas que estan que contien valores null
dropfila = list(nans.index)
df1 = df.drop(dropfila)

# %%
df1
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#Invertir las filas por columnas
df2=df1.T

# %%
df2
# Out:
#                                                                     0      \
# Case Number                                                    2018.06.25
# Date                                                          25-Jun-2018
# Year                                                                 2018
# Type                                                              Boating
# Country                                                               USA
# Area                                                           California
# Location                                      Oceanside, San Diego County
# Activity                                                         Paddling
# Name                                                          Julie Wolfe
# Sex                                                                     F
# Age                                                                    57
# Injury                  No injury to occupant, outrigger canoe and pad...
# ...

# %%
#ubicar las columnas con valores null
null_cols = df2.isnull().sum()
null_cols[null_cols > 0]
# Out:
# 0         2
# 1         3
# 2         3
# 3         4
# 4         4
#          ..
# 8698     23
# 8699     23
# 8700     23
# 8701     23
# 25722    23
# Length: 8703, dtype: int64

# %%
#eliminar las columnas con valores NaN mayores o iguales a 23
drop_cols = list(null_cols[null_cols >= 23].index)
df3 = df2.drop(drop_cols, axis=1)

# %%
df3
# Out:
#                                                                      0     \
# Case Number                                                    2018.06.25
# Date                                                          25-Jun-2018
# Year                                                                 2018
# Type                                                              Boating
# Country                                                               USA
# Area                                                           California
# Location                                      Oceanside, San Diego County
# Activity                                                         Paddling
# Name                                                          Julie Wolfe
# Sex                                                                     F
# Age                                                                    57
# Injury                  No injury to occupant, outrigger canoe and pad...
# ...

# %%
#ahora que puedo visualizar de mejor manera eliminaré nuevamente pero ahora con columnas > a 20 (valores Nan)
drop_cols = list(null_cols[null_cols > 20].index)
df3 = df2.drop(drop_cols, axis=1)

# %%
df3
# Out:
#                                                                      0     \
# Case Number                                                    2018.06.25
# Date                                                          25-Jun-2018
# Year                                                                 2018
# Type                                                              Boating
# Country                                                               USA
# Area                                                           California
# Location                                      Oceanside, San Diego County
# Activity                                                         Paddling
# Name                                                          Julie Wolfe
# Sex                                                                     F
# Age                                                                    57
# Injury                  No injury to occupant, outrigger canoe and pad...
# ...

# %%
#Realizo copia
df4 = df3.copy()

# %%
#Invierto Nuevamente mi DF 
df3=df3.T
df3
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
#ahora procedo a realizar nuevamente la operacion para eliminar las columnas con valores Nan > a 20
df3
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
null_cols1 = df3.isnull().sum()
null_cols1[null_cols1 > 0]
# Out:
# Case Number                  1
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
drop_cols2 = list(null_cols1[null_cols1 >= 6300].index)
df5 = df3.drop(drop_cols2, axis=1)

# %%
df5
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
df4 = df5.copy
#df4 es una copia

# %%
df5 = df5.fillna(0)

# %%
df5
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6302 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6302 non-null   float64
#  3   Type                    6302 non-null   object
#  4   Country                 6302 non-null   object
#  5   Area                    6302 non-null   object
#  6   Location                6302 non-null   object
#  7   Activity                6302 non-null   object
#  8   Name                    6302 non-null   object
#  9   Sex                     6302 non-null   object
#  10  Age                     6302 non-null   object
#  11  Injury                  6302 non-null   object
#  12  Fatal (Y/N)             6302 non-null   object
#  13  Time                    6302 non-null   object
# ...

# %%
#Elimino las columnas Case Number.1 y Case Number.2 ya que contienen los mismos valores de Case Number
df5.drop(['Case Number.1','Case Number.2'],inplace = True, axis = 1)
df5
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
df5.head(20)
# Out:
#      Case Number                  Date    Year          Type       Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
#Realizando un analisis de los campos Case Number y original order veo lo siguiente, en case number, muestra la fecha en la que se registró
#el caso, pero adicional ya existe el campo fecha(Date) puedo ver qué si en un mismo día hubo dos casos se registra uno como a y el siguiente como b
# y si uno sucedió dias antes pero se reportá ese dia se agrega el valor R. 
# mi consideración es la siguiente como no muestra la fecha probable real de accidente si no que el registro en case number y date son iguales
# elminar el campo case number
#ahora para el campo original order, esta mostrado de manera desc la cantidad de casos que hay sé puede decidir sí, ordenar la data
#con la información mas nueva ó ordenarla desde la primer en original order(que sería el ataque mas antiguo registrado)

# %%
df6 = df5.sort_values('original order')
df6.head(10)
# Out:
#      Case Number         Date  Year        Type             Country  \
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6296     ND.0006  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6295     ND.0007  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6294     ND.0008  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6293     ND.0009  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6292     ND.0010   Circa 1862   0.0  Unprovoked                 USA
#
#                    Area                             Location      Activity  \
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
# ...

# %%
#Ordenando de esta manera podemos observar que los primero ataques no tienen un registro valido para el campo date

# %%
df5.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  11
# 2                    Habush, Oahu      Surfing      John Denges    M  48
# 3              Arrawarra Headland      Surfing             male    M   0
# 4                        La Ticla  Free diving   Gustavo Ramos     M   0
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
import re
df5['Date'].apply(lambda x: re.findall('\d{4}$', x))
# Out:
# 0       [2018]
# 1       [2018]
# 2       [2018]
# 3       [2018]
# 4       [2018]
#          ...
# 6297    [1903]
# 6298    [1903]
# 6299    [1905]
# 6300    [1889]
# 6301    [1853]
# Name: Date, Length: 6302, dtype: object

# %%
df5['Year']= df5['Date'].apply(lambda x: re.findall('\d{4}$', x))

# %%
#Eliminar los corchetes que se agregaron en la columna Year
df5["Year"]=(df5["Year"].apply(lambda x: ",".join(x)))

# %%
df5
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  1905  Unprovoked                 USA
# 6300     ND.0002    1883-1889  1889  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  1853  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
#En vista que la columna Case Number no aporta información se elimina
df5.drop(['Case Number'], axis = 'columns', inplace=True)

# %%
#Elimino la columna href, no aporta información al igual que href formula y pdf
df5.drop(['href','href formula','pdf'], axis='columns', inplace=True)
df5
# Out:
#              Date  Year        Type             Country               Area  \
# 0     25-Jun-2018  2018     Boating                 USA         California
# 1     18-Jun-2018  2018  Unprovoked                 USA            Georgia
# 2     09-Jun-2018  2018     Invalid                 USA             Hawaii
# 3     08-Jun-2018  2018  Unprovoked           AUSTRALIA    New South Wales
# 4     04-Jun-2018  2018    Provoked              MEXICO             Colima
# ...           ...   ...         ...                 ...                ...
# 6297  Before 1903  1903  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903  1903  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905  1905  Unprovoked                 USA     North Carolina
# 6300    1883-1889  1889  Unprovoked              PANAMA                  0
# 6301    1845-1853  1853  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# ...

# %%
print(df5.Activity.value_counts())
# Out:
# Surfing                                                                971
# Swimming                                                               869
# 0                                                                      544
# Fishing                                                                431
# Spearfishing                                                           333
#                                                                       ...
# His balloon crashed in the harbor                                        1
# Swimming / floating on his back                                          1
# Competing in a light tackle game fishing                                 1
# Fishing from rocks, swept out to sea by large wave & treading water      1
# Fell or jumped overboard from the liner Rhynland                         1
# Name: Activity, Length: 1533, dtype: int64

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    6302 non-null   object
#  1   Year                    6302 non-null   object
#  2   Type                    6302 non-null   object
#  3   Country                 6302 non-null   object
#  4   Area                    6302 non-null   object
#  5   Location                6302 non-null   object
#  6   Activity                6302 non-null   object
#  7   Name                    6302 non-null   object
#  8   Sex                     6302 non-null   object
#  9   Age                     6302 non-null   object
#  10  Injury                  6302 non-null   object
#  11  Fatal (Y/N)             6302 non-null   object
#  12  Time                    6302 non-null   object
#  13  Species                 6302 non-null   object
# ...

# %%
# OK.. el siguiente paso para limpiar mi data y tener información mas consolidada, evaluando el count anterior es tomar solo las actividades con mas cantidad de registros
# Y omitiendo los que tienen valor 0, ya que en codigo más arriba se utilizó fillna y reemplazó Nan por cero
#Ademas para realizar algún analisis no nos sirve no tener un registro sin la actividad que realizaba la persona

# %%
df5['Activity'] = df5['Activity'].astype('str')

# %%
df6 = df5[(df5['Activity'] == 'Surfing')|(df5['Activity'] == 'Swimming')|(df5['Activity'] == 'Fishing')|(df5['Activity'] == 'Spearfising')]

# %%
df6
# Out:
#              Date  Year        Type             Country              Area  \
# 2     09-Jun-2018  2018     Invalid                 USA            Hawaii
# 3     08-Jun-2018  2018  Unprovoked           AUSTRALIA   New South Wales
# 6     03-Jun-2018  2018  Unprovoked              BRAZIL        Pernambuco
# 7     27-May-2018  2018  Unprovoked                 USA           Florida
# 12    13-May-2018  2018  Unprovoked                 USA    South Carolina
# ...           ...   ...         ...                 ...               ...
# 6294  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6295  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6296  Before 1906  1906  Unprovoked           AUSTRALIA   New South Wales
# 6299    1900-1905  1905  Unprovoked                 USA    North Carolina
# 6301    1845-1853  1853  Unprovoked  CEYLON (SRI LANKA)  Eastern Province
#
#                                                Location  Activity  \
# ...

# %%
#Ok en vista que el rango de fecha es bastante amplio y hay muchos registros donde no tengo su mes y día, pero para todos tengo el año
#los analisis que podría realizar pueden ser por años, también tengo el campo Country y Area

# %%
#asi como en Activity haré lo mismo para Injury

# %%
print(df6.Injury.value_counts())
# Out:
# FATAL                                                255
# Foot bitten                                           47
# Left foot bitten                                      30
# Leg bitten                                            27
# Right foot bitten                                     25
#                                                     ...
# Disappeared & his torn clothing washed ashore          1
# Puncture wound on arm                                  1
# Laceration & puncture wounds to right flank & hip      1
# FATAL, leg severely bitten                             1
# Cuts to dorsal surface of left foot                    1
# Name: Injury, Length: 1418, dtype: int64

# %%
#"Ok en vista que en campo injury hay muchos fatal y los otros mayormente son leciones pero especifican el lugar de la lesión, solo por 
#simplificar la columna y digamos de alguna manera limpiarla agregaremos una columna llamada Hurt donde solo encontraremos Fatal y Ijury
#Se va a eliminar la columna injury

# %%
df6['hurt'] = np.where(df6['Injury'].str.contains('FATAL', regex = False),'Fatal','Injury')
df6
# Out:
# <ipython-input-179-2763151f6e89>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['hurt'] = np.where(df6['Injury'].str.contains('FATAL', regex = False),'Fatal','Injury')
#              Date  Year        Type             Country              Area  \
# 2     09-Jun-2018  2018     Invalid                 USA            Hawaii
# 3     08-Jun-2018  2018  Unprovoked           AUSTRALIA   New South Wales
# 6     03-Jun-2018  2018  Unprovoked              BRAZIL        Pernambuco
# 7     27-May-2018  2018  Unprovoked                 USA           Florida
# 12    13-May-2018  2018  Unprovoked                 USA    South Carolina
# ...           ...   ...         ...                 ...               ...
# ...

# %%
df6.drop(['Injury'], axis='columns', inplace=True)
# Out:
# C:\Users\Mercantil\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df6
# Out:
#              Date  Year        Type             Country              Area  \
# 2     09-Jun-2018  2018     Invalid                 USA            Hawaii
# 3     08-Jun-2018  2018  Unprovoked           AUSTRALIA   New South Wales
# 6     03-Jun-2018  2018  Unprovoked              BRAZIL        Pernambuco
# 7     27-May-2018  2018  Unprovoked                 USA           Florida
# 12    13-May-2018  2018  Unprovoked                 USA    South Carolina
# ...           ...   ...         ...                 ...               ...
# 6294  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6295  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6296  Before 1906  1906  Unprovoked           AUSTRALIA   New South Wales
# 6299    1900-1905  1905  Unprovoked                 USA    North Carolina
# 6301    1845-1853  1853  Unprovoked  CEYLON (SRI LANKA)  Eastern Province
#
#                                                Location  Activity  \
# ...

# %%
#Ahora evaluando lo que tengo veo que ya existía el campo fatal, pero... para que el esfuerzo valga la pena eliminaré la columna fatal
#mantendré la nueva ya que con ella podemos sacar totales de cuantos son Fatal y cuantos Injury

# %%
df6.drop(['Fatal (Y/N)'], axis='columns', inplace=True)
# Out:
# C:\Users\Mercantil\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#pasé a otro DF para que no siguiera arrojando el error fatal
df7=df6

# %%
df7
# Out:
#              Date  Year        Type             Country              Area  \
# 2     09-Jun-2018  2018     Invalid                 USA            Hawaii
# 3     08-Jun-2018  2018  Unprovoked           AUSTRALIA   New South Wales
# 6     03-Jun-2018  2018  Unprovoked              BRAZIL        Pernambuco
# 7     27-May-2018  2018  Unprovoked                 USA           Florida
# 12    13-May-2018  2018  Unprovoked                 USA    South Carolina
# ...           ...   ...         ...                 ...               ...
# 6294  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6295  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6296  Before 1906  1906  Unprovoked           AUSTRALIA   New South Wales
# 6299    1900-1905  1905  Unprovoked                 USA    North Carolina
# 6301    1845-1853  1853  Unprovoked  CEYLON (SRI LANKA)  Eastern Province
#
#                                                Location  Activity  \
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2271 entries, 2 to 6301
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    2271 non-null   object
#  1   Year                    2271 non-null   object
#  2   Type                    2271 non-null   object
#  3   Country                 2271 non-null   object
#  4   Area                    2271 non-null   object
#  5   Location                2271 non-null   object
#  6   Activity                2271 non-null   object
#  7   Name                    2271 non-null   object
#  8   Sex                     2271 non-null   object
#  9   Age                     2271 non-null   object
#  10  Time                    2271 non-null   object
#  11  Species                 2271 non-null   object
#  12  Investigator or Source  2271 non-null   object
#  13  original order          2271 non-null   float64
# ...

# %%
print(df7.Age.value_counts())
# Out:
# 0              797
# 17              89
# 16              73
# 18              73
# 15              65
#               ...
# 5                1
# ?    &   14      1
# 50s              1
# 82               1
# 81               1
# Name: Age, Length: 103, dtype: int64

# %%
#Ok analizando un poco esto... sabemos que la mayor cantidad de muertes es por gente surfiando, pero nuestra mayor cantidad de registros tienen valores 0
#recordando que anteriormente eran Nan
#ademas como ya tenemos las actividades a la hora de realizar un analisis podriamos poner rangos de edades promedio(pero eso sería ya en analisis)
#por lo tanto eliminaré esta columna 
#Sigamos evaluando para hacer drop con mas columnas si es necesario
#La columna Investigator or Source no la concidero necesaria ya que es un estudio muy amplio y puede existir un investigador por caso
#Entonces no valdria la pena mantenerlo
#Time no tiene de igual forma valores que ayuden a un analisis

# %%
df7.drop(['Age','Investigator or Source','Time'], axis='columns', inplace=True)
df7
# Out:
# C:\Users\Mercantil\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#              Date  Year        Type             Country              Area  \
# 2     09-Jun-2018  2018     Invalid                 USA            Hawaii
# 3     08-Jun-2018  2018  Unprovoked           AUSTRALIA   New South Wales
# 6     03-Jun-2018  2018  Unprovoked              BRAZIL        Pernambuco
# 7     27-May-2018  2018  Unprovoked                 USA           Florida
# 12    13-May-2018  2018  Unprovoked                 USA    South Carolina
# ...           ...   ...         ...                 ...               ...
# 6294  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# ...

# %%
df7
# Out:
#              Date  Year        Type             Country              Area  \
# 2     09-Jun-2018  2018     Invalid                 USA            Hawaii
# 3     08-Jun-2018  2018  Unprovoked           AUSTRALIA   New South Wales
# 6     03-Jun-2018  2018  Unprovoked              BRAZIL        Pernambuco
# 7     27-May-2018  2018  Unprovoked                 USA           Florida
# 12    13-May-2018  2018  Unprovoked                 USA    South Carolina
# ...           ...   ...         ...                 ...               ...
# 6294  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6295  Before 1906  1906  Unprovoked           AUSTRALIA                 0
# 6296  Before 1906  1906  Unprovoked           AUSTRALIA   New South Wales
# 6299    1900-1905  1905  Unprovoked                 USA    North Carolina
# 6301    1845-1853  1853  Unprovoked  CEYLON (SRI LANKA)  Eastern Province
#
#                                                Location  Activity  \
# ...

# %%
print(df7['Species '].value_counts())
# Out:
# 0                                                                                             1010
# White shark                                                                                     61
# Shark involvement not confirmed                                                                 38
# Tiger shark                                                                                     28
# Shark involvement prior to death was not confirmed                                              23
#                                                                                               ...
# Bull shark, 2.5m                                                                                 1
# Questionable incident; reported as shark attack but thought to involve a pinniped instead        1
# 7 shark's teeth found embedded in the woodwork of the boat                                       1
# ...

# %%
#ok con esto queria saber si valia la pena mantener la columna, pero en vista a que hay tantos valores Nan, es recomendable eliminar, de igual forma 
#sabemos que son ataques de tiburon 
#eliminaremos Date,Names y Species
#Eliminaré date ya que no tengo otro dato importante que extraer, ya tenemos el año
#names, no es necesario

# %%
df7.drop(['Date','Name','Species '], axis='columns', inplace=True)
df7
# Out:
# C:\Users\Mercantil\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       Year        Type             Country              Area  \
# 2     2018     Invalid                 USA            Hawaii
# 3     2018  Unprovoked           AUSTRALIA   New South Wales
# 6     2018  Unprovoked              BRAZIL        Pernambuco
# 7     2018  Unprovoked                 USA           Florida
# 12    2018  Unprovoked                 USA    South Carolina
# ...    ...         ...                 ...               ...
# 6294  1906  Unprovoked           AUSTRALIA                 0
# 6295  1906  Unprovoked           AUSTRALIA                 0
# 6296  1906  Unprovoked           AUSTRALIA   New South Wales
# ...

# %%
#type no aporta información
df7.drop(['Type'], axis='columns', inplace=True)
df7
# Out:
# C:\Users\Mercantil\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       Year             Country              Area  \
# 2     2018                 USA            Hawaii
# 3     2018           AUSTRALIA   New South Wales
# 6     2018              BRAZIL        Pernambuco
# 7     2018                 USA           Florida
# 12    2018                 USA    South Carolina
# ...    ...                 ...               ...
# 6294  1906           AUSTRALIA                 0
# 6295  1906           AUSTRALIA                 0
# 6296  1906           AUSTRALIA   New South Wales
# 6299  1905                 USA    North Carolina
# 6301  1853  CEYLON (SRI LANKA)  Eastern Province
#
# ...

# %%
#Finalmente considero que tenemos una tabla bastante limpia y con datos relevante para un analisis

# %%
dffinal=df7
dffinal
# Out:
#       Year             Country              Area  \
# 2     2018                 USA            Hawaii
# 3     2018           AUSTRALIA   New South Wales
# 6     2018              BRAZIL        Pernambuco
# 7     2018                 USA           Florida
# 12    2018                 USA    South Carolina
# ...    ...                 ...               ...
# 6294  1906           AUSTRALIA                 0
# 6295  1906           AUSTRALIA                 0
# 6296  1906           AUSTRALIA   New South Wales
# 6299  1905                 USA    North Carolina
# 6301  1853  CEYLON (SRI LANKA)  Eastern Province
#
#                                                Location  Activity Sex   \
# 2                                          Habush, Oahu   Surfing    M
# 3                                    Arrawarra Headland   Surfing    M
# 6                                 Piedade Beach, Recife  Swimming    M
# 7     Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing    M
# ...

# %%
dffinal.to_csv('Pandas_project.csv', header=True , index=False)

# %%
dffinal
# Out:
#       Year             Country              Area  \
# 2     2018                 USA            Hawaii
# 3     2018           AUSTRALIA   New South Wales
# 6     2018              BRAZIL        Pernambuco
# 7     2018                 USA           Florida
# 12    2018                 USA    South Carolina
# ...    ...                 ...               ...
# 6294  1906           AUSTRALIA                 0
# 6295  1906           AUSTRALIA                 0
# 6296  1906           AUSTRALIA   New South Wales
# 6299  1905                 USA    North Carolina
# 6301  1853  CEYLON (SRI LANKA)  Eastern Province
#
#                                                Location  Activity Sex   \
# 2                                          Habush, Oahu   Surfing    M
# 3                                    Arrawarra Headland   Surfing    M
# 6                                 Piedade Beach, Recife  Swimming    M
# 7     Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing    M
# ...
