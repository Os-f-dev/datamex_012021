# %%
import pymongo
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import folium

# %% [markdown]
# ## Cargar base datos

# %%
cliente = pymongo.MongoClient()

# %%
cliente.list_database_names()
# Out:
# ['admin', 'companies', 'config', 'local']

# %%
db = cliente.companies

# %%
colec = db.companies

# %% [markdown]
# Obtendré información sobre la ubicación de las oficinas, el nombre de la empresa, su categoría, su descripción, el año de fundación y el número de empleados que tiene

# %%
oficinas = colec.find({'offices':{'$not':{'$size':0}}},
                         {'name':True,'_id':0,'category_code':1,'founded_year':1,'description':1 ,'number_of_employees':1, 'offices':1})

# %%
si_oficinas = list(oficinas)
si_oficinas[:10]
# Out:
# [{'name': 'Wetpaint',
#   'category_code': 'web',
#   'number_of_employees': 47,
#   'founded_year': 2005,
#   'description': 'Technology Platform Company',
#   'offices': [{'description': '',
#     'address1': '710 - 2nd Avenue',
#     'address2': 'Suite 1100',
#     'zip_code': '98104',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.603122,
#     'longitude': -122.333253},
#    {'description': '',
#     'address1': '270 Lafayette Street',
#     'address2': 'Suite 505',
#     'zip_code': '10012',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7237306,
#     'longitude': -73.9964312}]},
#  {'name': 'AdventNet',
#   'category_code': 'enterprise',
#   'number_of_employees': 600,
#   'founded_year': 1996,
#   'description': 'Server Management Software',
#   'offices': [{'description': 'Headquarters',
#     'address1': '4900 Hopyard Rd.',
#     'address2': 'Suite 310',
#     'zip_code': '94588',
#     'city': 'Pleasanton',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.692934,
#     'longitude': -121.904945}]},
#  {'name': 'Zoho',
#   'category_code': 'software',
#   'number_of_employees': 1600,
#   'founded_year': 2005,
#   'description': 'Online Business Apps Suite',
#   'offices': [{'description': 'Headquarters',
#     'address1': '4900 Hopyard Rd',
#     'address2': 'Suite 310',
#     'zip_code': '94588',
#     'city': 'Pleasanton',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.692934,
#     'longitude': -121.904945}]},
#  {'name': 'Digg',
#   'category_code': 'news',
#   'number_of_employees': 60,
#   'founded_year': 2004,
#   'description': 'user driven social content website',
#   'offices': [{'description': None,
#     'address1': '135 Mississippi St',
#     'address2': '',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.764726,
#     'longitude': -122.394523}]},
#  {'name': 'Facebook',
#   'category_code': 'social',
#   'number_of_employees': 5299,
#   'founded_year': 2004,
#   'description': 'Social network',
#   'offices': [{'description': 'Headquarters',
#     'address1': '1601 Willow Road',
#     'address2': '',
#     'zip_code': '94025',
#     'city': 'Menlo Park',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.41605,
#     'longitude': -122.151801},
#    {'description': 'Europe HQ',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Dublin',
#     'state_code': None,
#     'country_code': 'IRL',
#     'latitude': 53.344104,
#     'longitude': -6.267494},
#    {'description': 'New York',
#     'address1': '340 Madison Ave',
#     'address2': '',
#     'zip_code': '10017',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7557162,
#     'longitude': -73.9792469}]},
#  {'name': 'Omnidrive',
#   'category_code': 'network_hosting',
#   'number_of_employees': None,
#   'founded_year': 2005,
#   'description': None,
#   'offices': [{'description': '',
#     'address1': 'Suite 200',
#     'address2': '654 High Street',
#     'zip_code': '94301',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Postini',
#   'category_code': 'web',
#   'number_of_employees': None,
#   'founded_year': 1999,
#   'description': None,
#   'offices': [{'description': None,
#     'address1': '959 Skyway Road, Suite 200',
#     'address2': None,
#     'zip_code': '94070',
#     'city': 'San Carlos',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.506885,
#     'longitude': -122.247573}]},
#  {'name': 'Geni',
#   'category_code': 'web',
#   'number_of_employees': 18,
#   'founded_year': 2006,
#   'description': 'Geneology social network site',
#   'offices': [{'description': 'Headquarters',
#     'address1': '9229 W. Sunset Blvd.',
#     'address2': '',
#     'zip_code': '90069',
#     'city': 'West Hollywood',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.090368,
#     'longitude': -118.393064}]},
#  {'name': 'Flektor',
#   'category_code': 'games_video',
#   'number_of_employees': None,
#   'founded_year': None,
#   'description': None,
#   'offices': [{'description': None,
#     'address1': '8536 National Blvd, Suite A',
#     'address2': None,
#     'zip_code': '90232',
#     'city': 'Culver City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.025958,
#     'longitude': -118.379768}]},
#  {'name': 'Fox Interactive Media',
#   'category_code': 'web',
#   'number_of_employees': 0,
#   'founded_year': 1979,
#   'description': '',
#   'offices': [{'description': '',
#     'address1': '407 N Maple Dr',
#     'address2': '',
#     'zip_code': '90210',
#     'city': 'Beverly Hills',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.076179,
#     'longitude': -118.39417}]}]

# %%
df = pd.DataFrame(si_oficinas)
df
# Out:
#                       name category_code  number_of_employees  founded_year  \
# 0                 Wetpaint           web                 47.0        2005.0
# 1                AdventNet    enterprise                600.0        1996.0
# 2                     Zoho      software               1600.0        2005.0
# 3                     Digg          news                 60.0        2004.0
# 4                 Facebook        social               5299.0        2004.0
# ...                    ...           ...                  ...           ...
# 13739               Oriact      software                  NaN        2009.0
# 13740               Adhunk   advertising                  3.0        2009.0
# 13741           AfterLogic      software                  NaN        2002.0
# 13742  EnteGreat Solutions      software                  NaN           NaN
# 13743            EnteGreat    enterprise                  NaN        2000.0
#
#                               description  \
# 0             Technology Platform Company
# 1              Server Management Software
# 2              Online Business Apps Suite
# 3      user driven social content website
# 4                          Social network
# ...                                   ...
# 13739  Solutions for software development
# 13740                    Online Admanager
# 13741   .NET Email Components and Webmail
# 13742
# 13743
#
#                                                  offices
# 0      [{'description': '', 'address1': '710 - 2nd Av...
# 1      [{'description': 'Headquarters', 'address1': '...
# 2      [{'description': 'Headquarters', 'address1': '...
# 3      [{'description': None, 'address1': '135 Missis...
# 4      [{'description': 'Headquarters', 'address1': '...
# ...                                                  ...
# 13739  [{'description': '', 'address1': 'LÃ¤rchenweg ...
# 13740  [{'description': 'Indian Office', 'address1': ...
# 13741  [{'description': 'Livingston', 'address1': 'P....
# 13742  [{'description': '', 'address1': '', 'address2...
# 13743  [{'description': '', 'address1': '1900 Interna...
#
# [13744 rows x 6 columns]

# %%
lista_direcciones = [json_normalize(i) for i in df['offices']]

# %%
lista_nombres = list(df['name'])
lista_cc=list(df['category_code'])
lista_ne=list(df['number_of_employees'])
lista_fy=list(df['founded_year'])

# %%
print(len(lista_nombres), len(lista_direcciones))
# Out:
# 13744 13744

# %%
zip_nombre_df = list(zip(lista_nombres,lista_direcciones))

# %%
for i in zip_nombre_df:
    i[1]['name'] = i[0]

# %%
concat_df = pd.DataFrame()
for i in range(len(zip_nombre_df)):
    concat_df = pd.concat([concat_df,zip_nombre_df[i][1]])

# %%
df_co=pd.merge(df, concat_df, on='name')

# %%
df_co[:10]
# Out:
#         name    category_code  number_of_employees  founded_year  \
# 0   Wetpaint              web                 47.0        2005.0
# 1   Wetpaint              web                 47.0        2005.0
# 2  AdventNet       enterprise                600.0        1996.0
# 3       Zoho         software               1600.0        2005.0
# 4       Digg             news                 60.0        2004.0
# 5   Facebook           social               5299.0        2004.0
# 6   Facebook           social               5299.0        2004.0
# 7   Facebook           social               5299.0        2004.0
# 8  Omnidrive  network_hosting                  NaN        2005.0
# 9    Postini              web                  NaN        1999.0
#
#                         description_x description_y  \
# 0         Technology Platform Company
# 1         Technology Platform Company
# 2          Server Management Software  Headquarters
# 3          Online Business Apps Suite  Headquarters
# 4  user driven social content website          None
# 5                      Social network  Headquarters
# 6                      Social network     Europe HQ
# 7                      Social network      New York
# 8                                None
# 9                                None          None
#
#                      address1         address2 zip_code           city  \
# 0            710 - 2nd Avenue       Suite 1100    98104        Seattle
# 1        270 Lafayette Street        Suite 505    10012       New York
# 2            4900 Hopyard Rd.        Suite 310    94588     Pleasanton
# 3             4900 Hopyard Rd        Suite 310    94588     Pleasanton
# 4          135 Mississippi St                     94107  San Francisco
# 5            1601 Willow Road                     94025     Menlo Park
# 6                                                               Dublin
# 7             340 Madison Ave                     10017       New York
# 8                   Suite 200  654 High Street    94301      Palo Alto
# 9  959 Skyway Road, Suite 200             None    94070     San Carlos
#
#   state_code country_code   latitude   longitude    company
# 0         WA          USA  47.603122 -122.333253   Wetpaint
# 1         NY          USA  40.723731  -73.996431   Wetpaint
# 2         CA          USA  37.692934 -121.904945  AdventNet
# 3         CA          USA  37.692934 -121.904945       Zoho
# 4         CA          USA  37.764726 -122.394523       Digg
# 5         CA          USA  37.416050 -122.151801   Facebook
# 6       None          IRL  53.344104   -6.267494   Facebook
# 7         NY          USA  40.755716  -73.979247   Facebook
# 8         CA          ISR        NaN         NaN  Omnidrive
# 9         CA          USA  37.506885 -122.247573    Postini

# %% [markdown]
# ## Limpiando datos

# %%
df=df_co.copy()

# %%
df.dtypes #Se notan correctas, se modificarán nombres de columnas
# Out:
# name                    object
# category_code           object
# number_of_employees    float64
# founded_year           float64
# description_x           object
# description_y           object
# address1                object
# address2                object
# zip_code                object
# city                    object
# state_code              object
# country_code            object
# latitude               float64
# longitude              float64
# dtype: object

# %% [markdown]
# ## Explorando los datos y filtrando por preferencia personal

# %%
df['category_code'].unique()
# Out:
# array(['web', 'enterprise', 'software', 'news', 'social',
#        'network_hosting', 'games_video', 'music', 'mobile', 'search',
#        'advertising', 'messaging', 'security', 'photo_video', 'finance',
#        'hardware', 'ecommerce', 'travel', 'public_relations', 'other',
#        'real_estate', 'semiconductor', 'analytics', 'health', 'legal',
#        'sports', 'biotech', 'cleantech', 'education', 'consulting',
#        'transportation', 'hospitality', 'fashion', 'nonprofit',
#        'nanotech', 'automotive', None, 'design', 'manufacturing',
#        'government', 'local', 'medical'], dtype=object)

# %%
df_ms[df_ms['category_code']=='hospitality']
# Out:
#           name category_code  number_of_employees  founded_year  \
# 1698      Fluc   hospitality                  3.0        2013.0
# 7951  Foodista   hospitality                  3.0        2008.0
# 7952  Foodista   hospitality                  3.0        2008.0
# 7953  Foodista   hospitality                  3.0        2008.0
# 7954  Foodista   hospitality                  3.0        2008.0
#
#                                  description_x description_y  \
# 1698  Your Favorite Food. Delivered Instantly.
# 7951                               Recipe Wiki
# 7952                               Recipe Wiki
# 7953                               Recipe Wiki
# 7954                               Recipe Wiki
#
#                  address1   address2 zip_code        city state_code  \
# 1698  1259 El Camino Real               94025  Menlo Park         CA
# 7951       24 Roy Street,  Suite 210    98109     Seattle         WA
# 7952       24 Roy Street,  Suite 210    98109     Seattle         WA
# 7953       24 Roy Street,  Suite 210    98109     Seattle         WA
# 7954       24 Roy Street,  Suite 210    98109     Seattle         WA
#
#      country_code   latitude   longitude   company
# 1698          USA  37.454701 -122.185376      Fluc
# 7951          USA  47.625478 -122.356423  Foodista
# 7952          USA  47.625478 -122.356423  Foodista
# 7953          USA  47.625478 -122.356423  Foodista
# 7954          USA  47.625478 -122.356423  Foodista

# %%
df_ms=df[df['founded_year']>2005][df['number_of_employees']<200] #preferencia personal por empresas nuevas y con pocos empleados

# %%
df_ms['city'].value_counts()[:15].plot.pie(y='number', figsize=(20,10),autopct='%1.1f%%')
plt.title('Las 15 ciudades con más empresas millenials y menos de 200 empleados');

# %%
df_ms['category_code'].value_counts()[:15].plot.pie(y='number', figsize=(20,10),autopct='%1.1f%%')
plt.title('Tipo de empresas que se crearon después del 2005 y que tienen menos de 200 empleados');

# %% [markdown]
# ### Buscando el comportamiento a través del tiempo por ciudades y categoría

# %%
cities=['San Francisco', 'New York', 'London', 'Los Angeles','Amsterdam', 'Berlin' ]

# %%
categories= ['web', 'nonprofit', 'analytics', 'ecommerce', 'consulting', 'travel', 'finance', 'real_estate','education']

# %%
def city_category(city, cat):
    df_ms[df_ms['category_code']==f'{cat}'][df_ms['city']== f'{city}'].groupby('founded_year')['name'].count().plot()
    plt.title(f'Empresas {cat} creadas en diversas ciudades');

# %%
plt.figure(figsize = (15,10))
plt.subplots_adjust( hspace=0.4, bottom=0.4)
plt.subplot(2,2,1)
for i in cities:
    city_category(i, 'web')
    plt.legend(cities);
plt.subplot(2,2,2)
b
plt.subplot(2,2,3)
for i in cities:
    city_category(i, 'consulting')
    plt.legend(cities); 
plt.subplot(2,2,4)
for i in cities:
    city_category(i, 'games_video')
    plt.legend(cities);
# Out:
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# Se observa que en las categorías seleccionadas San Francisco es la que presenta más actividad, seguida por New York

# %% [markdown]
# ### Enfocandonos en ecommerce

# %%
df_ms[df_ms['category_code']=='ecommerce']['city'].value_counts()[:15].plot(kind='barh')
plt.title('Top 15 ciudades con más creación de empresas de ecommerce');

# %%
df_ms[df_ms['category_code']=='ecommerce']['city'].value_counts()[:15]
# Out:
# New York             23
# San Francisco        15
#                       9
# London                8
# Madrid                5
# Chicago               5
# Marina Del Rey        4
# Mountain View         4
# Wincanton             4
# Bangalore             4
# Holly Springs         4
# Pacific Palisades     4
# Brooklyn              4
# Sausalito             4
# Berlin                3
# Name: city, dtype: int64

# %% [markdown]
# ### Enfocandonos en ecommerce a lo largo del tiempo

# %%
cities= ['New York', 'London', 'Madrid', 'Chicago', 'Brooklyn', 'Berlin']

# %%
for i in cities:
    city_category(i, 'ecommerce')
    plt.legend(cities);
# Out:
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/estefhanymorenovega/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ### Enfocandonos en Madrid

# %%
df_mad=df_ms[df_ms['city']=='Madrid']

# %%
loc= list(zip(df_mad['latitude'], df_mad['longitude'])) #formando tuplas

# %%
loc
# Out:
# [(40.530724, -3.632687),
#  (40.43094, -3.6952896),
#  (nan, nan),
#  (40.5288449, -3.6429907),
#  (40.382338, -3.773844),
#  (nan, nan),
#  (40.4596242, -3.6923285),
#  (40.416741, -3.70325),
#  (40.42046, -3.678121),
#  (40.412323, -3.703248),
#  (40.412323, -3.703248),
#  (40.412323, -3.703248),
#  (40.412323, -3.703248),
#  (nan, nan),
#  (40.4367771, -3.6685036),
#  (40.4225487, -3.6830316),
#  (40.4380872, -3.6760635),
#  (nan, nan),
#  (40.6070897, -3.6912754),
#  (nan, nan),
#  (40.4905109, -3.7033403),
#  (40.4158236, -3.696277),
#  (40.4346935, -3.6782829),
#  (40.4165967, -3.6992667),
#  (40.6367104, -3.9980485),
#  (40.4226918, -3.6883074),
#  (40.4244585, -3.6990948)]

# %%
for i in range(len(loc)):
    try:
        folium.Marker([loc[i][0], loc[i][1]], icon=folium.Icon(color='red'),popup = '<b>Empresas con menos de 200 empleados creadas despues del 2005</b>', tooltip = 'tooltip').add_to(mapa2)
    except:
        pass
mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Top 10 global consumer trends in 2020 are:

# %%
import requests
from bs4 import BeautifulSoup

# %%
url= 'https://blog.euromonitor.com/top-10-global-consumer-trends-in-2020-revealed-by-euromonitor/'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
sopa = BeautifulSoup(req.content, 'html.parser')

# %%
p=sopa.find_all('p')

# %%
p_text= [i.text for i in p ]

# %%
p_text[4:6]
# Out:
# ['According to Euromonitor International, the top 10 global consumer trends in 2020 are:',
#  '• Beyond Human: Embracing artificial intelligence for automation and convenience.  • Catch Me in Seconds: Seeking quick, concise and multisensory content for instant gratification.  • Frictionless Mobility: Choosing transportation methods based on individual preferences for a seamless travel journey.  • Inclusive for All: Focusing on diversity and accessibility for everyone.  • Minding Myself: Prioritizing mental health and searching for products positioned to address specific well-being needs.  • Multifunctional Homes: Doing everything from the comfort of home.  • Private Personalization: Balancing the desire for optimized experiences with concerns about sharing personal data.  • Proudly Local, Going Global: Valuing home culture and products tailored to local tastes and preferences.  • Reuse Revolutionaries: Finding alternatives to single-use products to reduce environmental footprint and waste.  • We Want Clean Air Everywhere: Advocating for clean cities and a carbon-free world.']

# %%
for i in range(len(p_text)):
    p_text[i]=p_text[i].replace('\n','  ')
